# %% [markdown]
# # Build Excel stoich for GAMS (originally A01_build_excel_stoich_for_GAMS.ipynb)

# %% [markdown]
# #### Load data

# %%
import cobra,json,os,sys,openpyxl,re,pandas as pd
from collections import OrderedDict
from copy import deepcopy

model_root_path = '../'
sys.path.append(model_root_path)
from pycore.gsm_custom_functions import *
from pycore.cobrapy_custom_extras import *
kribo_default = 22*3600 #(22 aa/ribo/s converted to aa/ribo/h)
mito_compartments = ['m', 'mm'] # IDs for mitochondria compartments

# %%
# Metabolic model (COBRApy json)
# If you have to use multiple stoichiometric models (SMs), 
#   it's best to keep 1 as the main copy and then use transaction files to apply differences to the others. Helps improve consistency in annotations, stoich. etc.
chosen_model = 'Batch-Rabinowitz' # c: carbon, n: nitrogen

# List parameters for your model version(s), such as:
	# max_allowed_mito_proteome_allo_fraction: maximum fraction of proteome that can be allocated to mitochondria
	# nonmodeled_proteome_allocation: fraction of proteome not accounted for in the model
	# predicted_but_unused_proteins_path: path to file with predicted proteins that are not used in the model
	# sheet_name: name of sheet in relevant excel files (e.g., biomass, dummy protein) to use
# for 'Batch-Rabinowitz' before including nonmodeled proteins into model: 'nonmodeled_proteome_allocation':0.49,
modelVersions = {
	'Batch-Rabinowitz':{
		'max_allowed_mito_proteome_allo_fraction':0.13953,
		'nonmodeled_proteome_allocation':0,
		'predicted_but_unused_proteins_path':'%model_root_path%prosyn_constraints_predicted_but_unused_Rabinowitz2023_batchGlc_using_MFA_and_scRBA_methods.txt',
		'sheet_name':'batch-Rabinowitz'
	},
	'C':{
		'max_allowed_mito_proteome_allo_fraction':0.13464,
		'nonmodeled_proteome_allocation':0.54,
		'sheet_name':'chemo-clim-Rabinowitz'
	},
	'N':{
		'max_allowed_mito_proteome_allo_fraction':0.13033,
		'nonmodeled_proteome_allocation':0.53,
		'sheet_name':'chemo-nlim-Rabinowitz'
	}
	}
modelname = 'iRhto'+chosen_model
model = load_cobra_model('./input/'+modelname+'.json')
# if not choosing between nutrient-limited models, uncomment the following lines:
# model = cobra.io.load_json_model('./input/iRhtoC.json')
# chosen_model = ''

# Update GAMS settings file to reflect model version, 
#   and add NGAM, mito capacity, etc.
#   If not using multiple models, replace everything in the curly braces with the values you want
with open('./model/model-version-settings.txt', 'w') as f:
	npa = modelVersions[chosen_model].get('nonmodeled_proteome_allocation', 0)
	mampaf = modelVersions[chosen_model]['max_allowed_mito_proteome_allo_fraction'] if 'max_allowed_mito_proteome_allo_fraction' in modelVersions[chosen_model] else 1
	f.write(f"* file with settings updated by build_model scripts, to help with managing multiple SMs\n"
		f"$setGlobal max_allowed_mito_proteome_allo_fraction {mampaf}\n"
		f"$setGlobal nonmodeled_proteome_allocation {npa}\n")
	if 'measured_but_unused_proteins_path' in modelVersions[chosen_model]:
		f.write('* unless specified otherwise (e.g., in test_kapp.gms), include prosyn constraints to reflect production of unused proteins; comment out if using dummy protein instead\n')
		if modelVersions[chosen_model]['predicted_but_unused_proteins_path']:
			if os.path.exists(modelVersions[chosen_model]['predicted_but_unused_proteins_path']):
				f.write(f"$if not %ignore_measured_unused_constraints%==1 $include {modelVersions[chosen_model]['predicted_but_unused_proteins_path']}\n")

# Protein
df_pro = read_spreadsheet('./input/PROTEIN_stoich_curation.xlsx')
## OPTIONAL: add "special cases only" sheet to df_pro. 
##   Good for distinguishing proteins in the organism from ones added for testing purposes.
include_special_case_proteins = False # affects protein and enzyme stoichiometry
if include_special_case_proteins:
	df_pro_special = read_spreadsheet('./input/PROTEIN_stoich_curation.xlsx',sheet_name='special cases only',header=1)
	df_pro = pd.concat([df_pro,df_pro_special],ignore_index=True)

# Amino acid info
df_aamap = pd.read_csv('./input/PROTEIN_amino_acid_map.txt', sep='\t')
df_aamap.index = df_aamap.aa_abbv.to_list()

# Dummy protein
dummy_path = './input/PROTEIN_dummy_prot_calc.xlsx'
# df_aa_dummy = read_spreadsheet(dummy_path)
# df_aa_dummy2 = read_spreadsheet(dummy_path,sheet_name='unidentified')
# 1st entry is default dummy protein; remove 2nd entry unless needed
dummy_list = [{"df":read_spreadsheet(dummy_path,sheet_name=modelVersions[chosen_model]['sheet_name']),"name":"PROSYN-PROTDUMMY"},
			  {"df":read_spreadsheet(dummy_path,sheet_name='unidentified'),"name":"PROSYN-PROTDUMMYUNIDENTIFIED"}]
for prot in dummy_list:
	prot["df"].index = prot["df"].aa_abbv.to_list()
	prot["medianL"] = int(round(prot["df"].loc['A', 'Unnamed: 5'], 0))
	# Add 1e-5 g/mmol to prevent number round lost of protein MW
	#dummy_MW
	prot["MW"] = round(prot["df"].loc['C', 'Unnamed: 5'], 5) + 1e-5
	prot["biosyn"] = prot["name"].replace('PROSYN-','BIOSYN-')
	prot["met"] = prot["name"].lower().replace('prosyn-','BIO-')
	prot["translation_loc"] = 'unknown' if not 'translation_loc' in prot else prot['translation_loc']

# Enzyme
df_enz = read_spreadsheet('./input/ENZYME_stoich_curation.tsv')
# add 'id' column to df_enz, which is 'RXN-' + rxn_src + '_' + dir + '-' + enz
if include_special_case_proteins:
	df_enz_special = read_spreadsheet('./input/ENZYME_stoich_curation_special_cases.tsv')
	df_enz = pd.concat([df_enz,df_enz_special],ignore_index=True)

# RNA
df_rnas = read_spreadsheet('./input/RNA_stoich.xlsx')
df_rnas.index = df_rnas.RNAid.to_list()

# Ribosome ('_c' for nucleus or nucleoid, '_m' for mitochondria)
ribo_dict = {'_c':read_spreadsheet('./input/RIBOSOME_nucleus.xlsx'), 
			 '_m':read_spreadsheet('./input/RIBOSOME_mitochondria.xlsx')}

# Biomass
# heading start at cell X4
df_biom = read_spreadsheet('./input/BIOMASS_RBA.xlsx', sheet_name=modelVersions[chosen_model]['sheet_name'], header=4)
# concat with the other biomass sheet if needed (WARNING: should find a way to avoid having elements be redefined)
# df_biom = pd.concat([df_biom,read_spreadsheet('./input/BIOMASS_RBA.xlsx', sheet_name='batch-Rabinowitz+Pinheiro-macro', header=4)],ignore_index=True)
# df_biom = read_spreadsheet('./input/BIOMASS_RBA.xlsx', sheet_name='batch-Pinheiro', header=4)
# list of biomass rxns to turn off by default and only turn on when needed; any rxns not found will be excluded from list
whole_biomass_rxns = ['BIOSYN-' + i for i in ['BIODILAERO', 'BIODILAERO-NOGAM','BIOXYL-PINHEIRO','BIOXYL-PINHEIRO-NOGAM']] + ['BIOMASS_xyl_hybrid']

# checks which rxns to ignore when seeing if all necessary enzymes are modeled. Ignore blocked rxns (to avoid unnecessary work from adding them)
rxns_not_needing_enzymes = list(dict.fromkeys([r.id for r in model.reactions if r.bounds == (0,0)] + [rxn.id for rxn in find_biomass_reactions(model)] + ['BIOMASS_MFA','BIOMASS_MFA_NO_GAM','BIOMASS_RBA']))
# Gene-Protein Reaction associations (GPRs) representing spontaneous reactions (i.e., no enzyme needed in model)
spont_GPRs = ['SPONT', 'UNKNOWN']
# take IDs of all rxns
print('Reactions to ignore when checking if enzymes must be added:')
print(rxns_not_needing_enzymes)
# Out:
# Reactions to ignore when checking if enzymes must be added:
# ['ABTD2Dy_c', 'ABTD4Dy_c', 'ABTLD_c', 'ACALDt_c_m', 'ACOAO100_x', 'ACOAO120_x', 'ACOAO40_x', 'ACOAO60_x', 'ACOAO80_x', 'ALCD2i2_c', 'ASNtps_v', 'ASPtps_v', 'BIOMASS_RBA', 'BIOMASS_MFA', 'BIOMASS_MFA_NO_GAM', 'BIOMASS_PinheiroEtAl2020', 'BIOMASS_xyl_hybrid', 'CTPS1_c', 'CYSItps_v', 'DDPA_m', 'EX_fald_e', 'FER_c', 'G3PD1i_m', 'GLNtps_v', 'GLUtps_v', 'GLYAT_c', 'HMGCOAS_m', 'ILEtps_v', 'LEUtps_v', 'NITRy_c', 'PHCHGS_m', 'PKETF_c', 'TYRtps_v', 'XU5PFGT_x', 'XYLI1_c', 'XYLI2_c', 'XYLK_c', 'XYLURx_c', 'XYLURy_c', 'BIOMASS']

# %%
# Expanding df_pro to include sublocations as separate proteins
## remove the 'id' column
df_pro = df_pro.drop(columns=['id'])
# if the 'gene_src' column is empty, fill it with the 'name' column
df_pro['gene_src'] = df_pro['gene_src'].fillna(df_pro['name'])
## for each protein, if there are commas in subloc_assigned, split them into separate entries with 'id' modified to reflect sublocation
df_pro['subloc_assigned'] = df_pro['subloc_assigned'].apply(lambda x: x.split(',') if type(x) == str and ',' in x else x)
# add the 'id' column back in, assigning it to "gene_src" plus "subloc_assigned" if the latter is not 'unknown'
# modify IDs to reflect sublocation
# add location only if there are multiple proteins with the same gene source
df_pro = df_pro.explode('subloc_assigned').reset_index(drop=True)
if 'id' not in df_pro.columns:
	df_pro['id'] = df_pro.apply(
		lambda row: row['id_manual_override (clear when using new sheet)']
		if pd.notna(row['id_manual_override (clear when using new sheet)'])
		else (
			str(row['gene_src'])
			+ (
				'_' + row['subloc_assigned']
				if row['subloc_assigned'] != 'unknown'
				and df_pro[df_pro['gene_src'] == row['gene_src']].shape[0] > 1
				else ''
			)
		),
		axis=1
	)
df_pro.index = df_pro.id.to_list()
# save df_pro to model folder
df_pro[['id'] + [col for col in df_pro.columns if col != 'id']].to_csv('./model/PROTEIN_stoich_curation.tsv', sep='\t', index=False)

# %%
# calculate MW of enzymes = sum of MW of all proteins in protein_stoich (MW from df_pro) * number of protein_stoich

# if there are any rows in df_enz with 'dir' that's empty, create 2 new rows for each of those, one with 'dir' as 'FWD' and one with 'dir' as 'REV' (for faster writing to model)
if df_enz['dir'].isnull().any():
	print('Enzyme stoichiometry has empty "dir" values. Creating FWD and REV entries for those enzymes.')
	df_enz_fwd = df_enz.copy()
	df_enz_fwd['dir'] = df_enz_fwd['dir'].fillna('FWD')
	df_enz_rev = df_enz.copy()
	df_enz_rev['dir'] = df_enz_rev['dir'].fillna('REV')
	df_enz = pd.concat([df_enz_fwd[df_enz_fwd['dir'] == 'FWD'], df_enz_rev[df_enz_rev['dir'] == 'REV']], ignore_index=True)
	# sort df_enz by 'rxn_src' and 'dir'
	df_enz = df_enz.sort_values(by=['rxn_src', 'dir']).reset_index(drop=True)
	# Now df_enz_new contains all original rows, plus FWD and REV for those missing 'dir'

df_enz['id'] = df_enz.apply(lambda x: 'RXN-' + x['rxn_src'] + '_' + x['dir'] + '-' + x['enz'], axis=1)
df_enz.index = df_enz.id.to_list()
mw = 'MW (g/mmol)'
for enz in df_enz.index:
	enz_mw = 0
	for pro in df_enz.loc[enz, 'protein_stoich'].split(','):
		# find protein stoichiometry in df_pro
		delim = ':'
		if delim in pro:
			prot_id = pro.split(delim)[0].strip()
			prot_stoich = float(pro.split(delim)[1].strip())
			pro_matches = df_pro.loc[df_pro.gene_src == prot_id]
			# if no matches, check if prot_id is in df_pro.index
			if len(pro_matches) == 0:
				if prot_id in df_pro.index:
					pro_matches = df_pro.loc[prot_id]
				else:
					print(f'Warning: {prot_id} not found in protein stoichiometry file')
					continue
			pro_mw = pro_matches[mw]
			if isinstance(pro_matches[mw], pd.Series):
				if pro_matches[mw].nunique() > 1:
					print(f'Warning: {prot_id} has multiple MWs in df_pro')
				pro_mw = pro_matches[mw].iloc[0]
			if float(pro_mw) == 0:
				print(f'Warning: MW for {prot_id} is 0 in protein stoichiometry file')
				continue
			enz_mw += pro_mw * prot_stoich
	# set enz_mw to NaN if it is 0
	if enz_mw == 0:
		enz_mw = float('nan')
	df_enz.loc[enz, mw] = enz_mw
# move 'id' column to the front
df_enz[['id'] + [col for col in df_enz.columns if col != 'id']].to_csv('./model/ENZYME_stoich_curation.tsv', sep='\t', index=False)
# Out:
# Enzyme stoichiometry has empty "dir" values. Creating FWD and REV entries for those enzymes.

# %%
# list all genes, to map them to translation (PROSYN) rxns and other rxns making their products where needed
# combine all genes from df_pro and model
# combine all genes from df_pro and model, ensuring all are strings and not NaN
genes_model = [str(gene.id) for gene in model.genes if pd.notna(gene.id)]
genes_pro = [str(g) for g in df_pro.gene_src.to_list() if pd.notna(g)]
genes_rna = [str(r) for r in df_rnas.RNAid.to_list() if pd.notna(r)]
genes = sorted(list(dict.fromkeys(genes_model + genes_pro + genes_rna)))
gene_expression_dict = {}

# %%
# testing only
# # tag_c formula weight
# # print(model.metabolites.get_by_id('tag_c').formula_weight-227.000000) # 227.000000 from Ac element accidentally listed in it
# # TAG MW is 89.07 w/o Acyl3, 882.40 w/ Acyl3 according to https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6838544/. Thus, Acyl MW is (882.40-89.07)/3 = 264.4433333333
# # calculate_molecular_weight('C28H43O')
# # (12.010700*28)+(1.007940*43)+15.999400 = 395.64042
# # print(model.metabolites.get_by_id('ergstest_c').formula_weight-227.000000+264.4433333333) # 227.000000 from Ac element accidentally listed in it
# print(model.metabolites.get_by_id('o2_c').formula_weight)

# %%
# Make version of model with no generic cofactors, for publication and for MEMOTE testing
model_no_generics = deepcopy(model)
# remove rxns with names beginning with "GENERIC_"
for rxn in model.reactions:
	if rxn.id.startswith("GENERIC_"):
		# print(rxn.id)
		model_no_generics.reactions.get_by_id(rxn.id).remove_from_model()
report_mass_balance(model_no_generics)
# remove metabolites with names beginning with "pseudometabolite "
for met in model.metabolites:
	if met.name.startswith("pseudometabolite "):
		# print(met.name)
		model_no_generics.metabolites.get_by_id(met.id).remove_from_model()
# write JSON version of the model w/o these additions (for future use)
cobra.io.save_json_model(model_no_generics, "./input/"+modelname+"-no-generic-cofactors.json")
# convert to xml file
cobra.io.write_sbml_model(model_no_generics, "./input/"+modelname+"-no-generic-cofactors.xml")
# Out:
# DM_5mta_c
# 5mta_c -->
# 5mta_c	C11H15N5O3S1	0	C00170	5'-S-methyl-5'-thioadenosine	biocyc
# C:-11, H:-15, N:-5, O:-3, S:-1, charge:0
#
# DM_gcald_c
# gcald_c -->
# gcald_c	C2H4O2	0	C00266	glycolaldehyde	biocyc
# C:-2, H:-4, O:-2, charge:0
#
# TORULNOXi_c
# o2_c + toruln_c --> 2.0 h_c + torularho_c
# h_c	H1	1	C00080	H+	biocyc
# o2_c	O2	0	C00007	oxygen	biocyc
# torularho_c	C40H52O2	0	      	Torularhodin	manual
# toruln_c	C40H54	0	C08613	Torulene	seed.compound
# H:0, O:0, C:0, charge:2
#
# compACYLCOA_c
# 0.01875 docoscoa_c + 0.355664 linocoa_c + 0.087612 linolncoa_c + 0.207129 odecoa_c + 0.1694 pmtcoa_c + 0.112806 stcoa_c + 0.048639 ttccoa_c <=> acylcoa_c
# acylcoa_c	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA	manual
# docoscoa_c	C43H74N7O17P3S1	-4	C16528	docosanoyl-CoA	biocyc
# linocoa_c	C39H62N7O17P3S	-4	C02050	linoleoyl-CoA	seed.compound
# linolncoa_c	C39H60N7O17P3S	-4	C16162	alpha-linolenoyl-CoA	seed.compound
# odecoa_c	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA	biocyc
# pmtcoa_c	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA	biocyc
# stcoa_c	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA	biocyc
# ttccoa_c	C45H78N7O17P3S	-4	C16529	tetracosanoyl-CoA	seed.compound
# C:-18.028033999999998, H:-32.693481999999996, N:3.3306690738754696e-16, O:-0.999999999999999, P:5.551115123125783e-17, S:-5.551115123125783e-17, Acyl:1, charge:2.220446049250313e-16
#
# compACYLCOA_l
# 0.01875 docoscoa_l + 0.355664 linocoa_l + 0.087612 linolncoa_l + 0.207129 odecoa_l + 0.1694 pmtcoa_l + 0.112806 stcoa_l + 0.048639 ttccoa_l <=> acylcoa_l
# acylcoa_l	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA	manual
# docoscoa_l	C43H74N7O17P3S1	-4	C16528	docosanoyl-CoA	biocyc
# linocoa_l	C39H62N7O17P3S	-4	C02050	linoleoyl-CoA	seed.compound
# linolncoa_l	C39H60N7O17P3S	-4	C16162	alpha-linolenoyl-CoA	seed.compound
# odecoa_l	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA	biocyc
# pmtcoa_l	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA	biocyc
# stcoa_l	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA	biocyc
# ttccoa_l	C45H78N7O17P3S	-4	C16529	tetracosanoyl-CoA	seed.compound
# C:-18.028033999999998, H:-32.693481999999996, N:3.3306690738754696e-16, O:-0.999999999999999, P:5.551115123125783e-17, S:-5.551115123125783e-17, Acyl:1, charge:2.220446049250313e-16
#
# compACYLCOA_m
# 0.01875 docoscoa_m + 0.355664 linocoa_m + 0.087612 linolncoa_m + 0.207129 odecoa_m + 0.1694 pmtcoa_m + 0.112806 stcoa_m + 0.048639 ttccoa_m <=> acylcoa_m
# acylcoa_m	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA	manual
# docoscoa_m	C43H74N7O17P3S1	-4	C16528	docosanoyl-CoA	biocyc
# linocoa_m	C39H62N7O17P3S	-4	C02050	linoleoyl-CoA	seed.compound
# linolncoa_m	C39H60N7O17P3S	-4	C16162	alpha-linolenoyl-CoA	seed.compound
# odecoa_m	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA	biocyc
# pmtcoa_m	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA	biocyc
# stcoa_m	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA	biocyc
# ttccoa_m	C45H78N7O17P3S	-4	C16529	tetracosanoyl-CoA	seed.compound
# C:-18.028033999999998, H:-32.693481999999996, N:3.3306690738754696e-16, O:-0.999999999999999, P:5.551115123125783e-17, S:-5.551115123125783e-17, Acyl:1, charge:2.220446049250313e-16
#
# compACYLCOA_r
# 0.01875 docoscoa_r + 0.355664 linocoa_r + 0.087612 linolncoa_r + 0.207129 odecoa_r + 0.1694 pmtcoa_r + 0.112806 stcoa_r + 0.048639 ttccoa_r <=> acylcoa_r
# acylcoa_r	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA	manual
# docoscoa_r	C43H74N7O17P3S1	-4	C16528	docosanoyl-CoA	biocyc
# linocoa_r	C39H62N7O17P3S	-4	C02050	linoleoyl-CoA	seed.compound
# linolncoa_r	C39H60N7O17P3S	-4	C16162	alpha-linolenoyl-CoA	seed.compound
# odecoa_r	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA	biocyc
# pmtcoa_r	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA	biocyc
# stcoa_r	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA	biocyc
# ttccoa_r	C45H78N7O17P3S	-4	C16529	tetracosanoyl-CoA	seed.compound
# C:-18.028033999999998, H:-32.693481999999996, N:3.3306690738754696e-16, O:-0.999999999999999, P:5.551115123125783e-17, S:-5.551115123125783e-17, Acyl:1, charge:2.220446049250313e-16
#
# compACYLCOA_rm
# 0.01875 docoscoa_rm + 0.355664 linocoa_rm + 0.087612 linolncoa_rm + 0.207129 odecoa_rm + 0.1694 pmtcoa_rm + 0.112806 stcoa_rm + 0.048639 ttccoa_rm <=> acylcoa_rm
# acylcoa_rm	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA	manual
# docoscoa_rm	C43H74N7O17P3S1	-4	C16528	docosanoyl-CoA	biocyc
# linocoa_rm	C39H62N7O17P3S	-4	C02050	linoleoyl-CoA	seed.compound
# linolncoa_rm	C39H60N7O17P3S	-4	C16162	alpha-linolenoyl-CoA	seed.compound
# odecoa_rm	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA	biocyc
# pmtcoa_rm	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA	biocyc
# stcoa_rm	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA	biocyc
# ttccoa_rm	C45H78N7O17P3S	-4	C16529	tetracosanoyl-CoA	seed.compound
# C:-18.028033999999998, H:-32.693481999999996, N:3.3306690738754696e-16, O:-0.999999999999999, P:5.551115123125783e-17, S:-5.551115123125783e-17, Acyl:1, charge:2.220446049250313e-16
#
# compACYLCOA_x
# 0.01875 docoscoa_x + 0.355664 linocoa_x + 0.087612 linolncoa_x + 0.207129 odecoa_x + 0.1694 pmtcoa_x + 0.112806 stcoa_x + 0.048639 ttccoa_x <=> acylcoa_x
# acylcoa_x	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA	manual
# docoscoa_x	C43H74N7O17P3S1	-4	C16528	docosanoyl-CoA	biocyc
# linocoa_x	C39H62N7O17P3S	-4	C02050	linoleoyl-CoA	seed.compound
# linolncoa_x	C39H60N7O17P3S	-4	C16162	alpha-linolenoyl-CoA	seed.compound
# odecoa_x	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA	biocyc
# pmtcoa_x	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA	biocyc
# stcoa_x	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA	biocyc
# ttccoa_x	C45H78N7O17P3S	-4	C16529	tetracosanoyl-CoA	seed.compound
# C:-18.028033999999998, H:-32.693481999999996, N:3.3306690738754696e-16, O:-0.999999999999999, P:5.551115123125783e-17, S:-5.551115123125783e-17, Acyl:1, charge:2.220446049250313e-16
#
# compCER_g
# 0.25 cer1_24_g + 0.25 cer1_26_g + 0.25 cer2A_24_g + 0.25 cer2A_26_g <=> cer_g
# cer1_24_g	C42H85N1O3	0	      	ceramide-1 (C24)	biocyc
# cer1_26_g	C44H89N1O3	0	      	ceramide-1 (C26)	biocyc
# cer2A_24_g	C42H85N1O4	0	      	ceramide-2 (C24)	biocyc
# cer2A_26_g	C44H89N1O4	0	      	ceramide-2 (C26)	biocyc
# cer_g	Cer	0	C00195	Ceramide	manual
# C:-43, H:-87, N:-1, O:-3.5, Cer:1, charge:0
#
# compCER_m
# 0.25 cer1_24_m + 0.25 cer1_26_m + 0.25 cer2A_24_m + 0.25 cer2A_26_m <=> cer_m
# cer1_24_m	C42H85N1O3	0	      	ceramide-1 (C24)	biocyc
# cer1_26_m	C44H89N1O3	0	      	ceramide-1 (C26)	biocyc
# cer2A_24_m	C42H85N1O4	0	      	ceramide-2 (C24)	biocyc
# cer2A_26_m	C44H89N1O4	0	      	ceramide-2 (C26)	biocyc
# cer_m	Cer	0	C00195	Ceramide	manual
# C:-43, H:-87, N:-1, O:-3.5, Cer:1, charge:0
#
# compCER_r
# 0.25 cer1_24_r + 0.25 cer1_26_r + 0.25 cer2A_24_r + 0.25 cer2A_26_r <=> cer_r
# cer1_24_r	C42H85N1O3	0	      	ceramide-1 (C24)	biocyc
# cer1_26_r	C44H89N1O3	0	      	ceramide-1 (C26)	biocyc
# cer2A_24_r	C42H85N1O4	0	      	ceramide-2 (C24)	biocyc
# cer2A_26_r	C44H89N1O4	0	      	ceramide-2 (C26)	biocyc
# cer_r	Cer	0	C00195	Ceramide	manual
# C:-43, H:-87, N:-1, O:-3.5, Cer:1, charge:0
#
# compFALPD_c
# 0.01875 docosa_c + 0.1694 hdca_c + 0.355664 linoea_c + 0.087612 linolen_c + 0.112806 ocdca_c + 0.207129 ocdcea_c + 0.048639 ttcosa_c <=> falpd_c
# docosa_c	C22H43O2	-1	C08281	docosanoate	seed.compound
# falpd_c	AcylO	-1	C00162	Fatty acid (from lipid)	manual
# hdca_c	C16H31O2	-1	C00249	palmitate	biocyc
# linoea_c	C18H31O2	-1	C01595	linoleate	seed.compound
# linolen_c	C18H29O2	-1	C06427	alpha-linolenate	seed.compound
# ocdca_c	C18H35O2	-1	C01530	stearate	biocyc
# ocdcea_c	C18H33O2	-1	C00712	oleate	biocyc
# ttcosa_c	C24H47O2	-1	C08320	tetracosanoate	seed.compound
# C:-18.028033999999998, H:-32.693482, O:-0.9999999999999999, Acyl:1, charge:6.938893903907228e-17
#
# compFALPD_en
# 0.01875 docosa_en + 0.1694 hdca_en + 0.355664 linoea_en + 0.087612 linolen_en + 0.112806 ocdca_en + 0.207129 ocdcea_en + 0.048639 ttcosa_en <=> falpd_en
# docosa_en	C22H43O2	-1	C08281	docosanoate	seed.compound
# falpd_en	AcylO	-1	C00162	Fatty acid (from lipid)	manual
# hdca_en	C16H31O2	-1	C00249	palmitate	biocyc
# linoea_en	C18H31O2	-1	C01595	linoleate	seed.compound
# linolen_en	C18H29O2	-1	C06427	alpha-linolenate	seed.compound
# ocdca_en	C18H35O2	-1	C01530	stearate	biocyc
# ocdcea_en	C18H33O2	-1	C00712	oleate	biocyc
# ttcosa_en	C24H47O2	-1	C08320	tetracosanoate	seed.compound
# C:-18.028033999999998, H:-32.693482, O:-0.9999999999999999, Acyl:1, charge:6.938893903907228e-17
#
# compFALPD_m
# 0.01875 docosa_m + 0.1694 hdca_m + 0.355664 linoea_m + 0.087612 linolen_m + 0.112806 ocdca_m + 0.207129 ocdcea_m + 0.048639 ttcosa_m <=> falpd_m
# docosa_m	C22H43O2	-1	C08281	docosanoate	seed.compound
# falpd_m	AcylO	-1	C00162	Fatty acid (from lipid)	manual
# hdca_m	C16H31O2	-1	C00249	palmitate	biocyc
# linoea_m	C18H31O2	-1	C01595	linoleate	seed.compound
# linolen_m	C18H29O2	-1	C06427	alpha-linolenate	seed.compound
# ocdca_m	C18H35O2	-1	C01530	stearate	biocyc
# ocdcea_m	C18H33O2	-1	C00712	oleate	biocyc
# ttcosa_m	C24H47O2	-1	C08320	tetracosanoate	seed.compound
# C:-18.028033999999998, H:-32.693482, O:-0.9999999999999999, Acyl:1, charge:6.938893903907228e-17
#
# compFALPD_mm
# 0.01875 docosa_mm + 0.1694 hdca_mm + 0.355664 linoea_mm + 0.087612 linolen_mm + 0.112806 ocdca_mm + 0.207129 ocdcea_mm + 0.048639 ttcosa_mm <=> falpd_mm
# docosa_mm	C22H43O2	-1	C08281	docosanoate	seed.compound
# falpd_mm	AcylO	-1	C00162	Fatty acid (from lipid)	manual
# hdca_mm	C16H31O2	-1	C00249	palmitate	biocyc
# linoea_mm	C18H31O2	-1	C01595	linoleate	seed.compound
# linolen_mm	C18H29O2	-1	C06427	alpha-linolenate	seed.compound
# ocdca_mm	C18H35O2	-1	C01530	stearate	biocyc
# ocdcea_mm	C18H33O2	-1	C00712	oleate	biocyc
# ttcosa_mm	C24H47O2	-1	C08320	tetracosanoate	seed.compound
# C:-18.028033999999998, H:-32.693482, O:-0.9999999999999999, Acyl:1, charge:6.938893903907228e-17
#
# compFALPD_rm
# 0.01875 docosa_rm + 0.1694 hdca_rm + 0.355664 linoea_rm + 0.087612 linolen_rm + 0.112806 ocdca_rm + 0.207129 ocdcea_rm + 0.048639 ttcosa_rm <=> falpd_rm
# docosa_rm	C22H43O2	-1	C08281	docosanoate	seed.compound
# falpd_rm	AcylO	-1	C00162	Fatty acid (from lipid)	manual
# hdca_rm	C16H31O2	-1	C00249	palmitate	biocyc
# linoea_rm	C18H31O2	-1	C01595	linoleate	seed.compound
# linolen_rm	C18H29O2	-1	C06427	alpha-linolenate	seed.compound
# ocdca_rm	C18H35O2	-1	C01530	stearate	biocyc
# ocdcea_rm	C18H33O2	-1	C00712	oleate	biocyc
# ttcosa_rm	C24H47O2	-1	C08320	tetracosanoate	seed.compound
# C:-18.028033999999998, H:-32.693482, O:-0.9999999999999999, Acyl:1, charge:6.938893903907228e-17

# %% [markdown]
# #### Assemble reactions

# %%
import itertools
import cobra.manipulation

def find_true_combinations(expression, use_knockout=False, variables:list=[]):
    """
    Finds all combinations of boolean values that make the given expression true.

    Args:
        expression: The boolean expression as a string.
        use_knockout: If True, the function will test combinations where only one variable is False, and use those to eliminate redundant combinations, saving time. Will return an error if the expression contains 'not' operators unless set to 'ignore warning'.
        variables: A list of strings (variable names in expression) to consider. If none provided, the function will extract variable names from the expression. Added in case consistent RegEx parsing proves too unreliable.
    Returns:
        A list of dictionaries, where each dictionary represents a true combination.

    """

    # Extract variables from the expression
    if variables == []:
        variables = set(re.findall(r'\b\w+\b', expression))
        if use_knockout and any([var in ['not','!'] for var in variables]):
            raise ValueError("The expression contains 'not' operators, which may cause issues with the 'use_knockout' option. If you still want to use this option, set it to 'ignore warning'.")
        # remove 'and', 'or', 'not' from variables
        variables = [var for var in variables if var not in ['and', 'or', 'not']]
    # print(variables)

    # Generate all possible combinations of True/False values for variables
    combinations = itertools.product([True, False], repeat=len(variables))
    # sort combinations from fewest to most True values
    combinations = sorted(combinations, key=lambda x: sum(x))
    combos_to_check = combinations.copy()
    # print(combinations)
    # find all combinations where only one variable is False
    knockout_combos = []
    essential_vars = [] # variables that must be True
    # test if combo where all variables are True makes the expression True
    all_true = dict(zip(variables, [True]*len(variables)))
    expr = expression
    for var in sorted(variables, key=len, reverse=True):
        expr = expr.replace(var, str(all_true[var]))
    if use_knockout != False:
        if eval(expr):
            # for each variable, find the combination where only that variable is False
            for var in variables:
                combo = [True]*len(variables)
                combo[variables.index(var)] = False
                knockout_combos.append(combo)
                expr = expression
                for var2 in sorted(variables, key=len, reverse=True):
                    expr = expr.replace(var2, str(combo[variables.index(var2)]))
                # add variable to essential_vars if it must be True
                if not eval(expr):
                    essential_vars.append(var)
                    # remove all combinations where this variable is False from combos_to_check
                    combos_to_check = [combo for combo in combos_to_check if combo[variables.index(var)]]
    # if len(combinations) != len(combos_to_check):
    #     print(f'Reduced combinations to check from {len(combinations)} to {len(combos_to_check)} by eliminating redundant combinations.')

    true_combinations = []
    for combo in combos_to_check:
        # Create a dictionary mapping variables to their assigned values
        values = dict(zip(variables, combo))
        # print(values)
        # print(combo)
        # replace variables with their values in 'values'
        # cobra.manipulation.knock_out_model_genes

        expr = expression
        # Replace variables with their values in the expression, starting with the longest variable names to avoid the risk of replacing substrings
        for var in sorted(variables, key=len, reverse=True):
            expr = expr.replace(var, str(values[var]))

        # print(expression)
        # print(expr,type(expr))
        # Evaluate the expression
        if eval(expr):
            # check if the combination's True values are a subset of any previous ones; if so, don't add it
            # print('\t',values)
            redundant_combos = False
            true_vals = [var for var in values if values[var]]
            for prev in true_combinations:
                prev_vals = [var for var in prev if prev[var]]
                if set(true_vals).issubset(set(prev_vals)) or set(prev_vals).issubset(set(true_vals)):
                    redundant_combos = True
                    # print('redundant:',true_vals)
                    break
            if not redundant_combos:
                true_combinations.append(values)

    return true_combinations

# Example usage:
expression = "rt05 and ((rt01 and (rt012 or rt0123)) or rt04)"
true_combos = find_true_combinations(expression, use_knockout=True)
print(true_combos)
# Out:
# [{'rt04': True, 'rt012': False, 'rt05': True, 'rt01': False, 'rt0123': False}, {'rt04': False, 'rt012': True, 'rt05': True, 'rt01': True, 'rt0123': False}, {'rt04': False, 'rt012': False, 'rt05': True, 'rt01': True, 'rt0123': True}]

# %%
# Automatically create placeholders for enzymes based on GPRs in model.reactions
rxns_to_skip = set(rxns_not_needing_enzymes)
enz_rxn_dict = {}
spont_rxn_dict = {}
rxn_updates = {rxn.id: {} for rxn in model.reactions}
GPR_enz_dict = {}
try:
	df_enz_rxns = read_spreadsheet('./input/ENZYME_stoich.tsv')
	# make set of rxns to skip, from combining the 'rxns' column cells in df_enz_rxns (to avoid reviewing existing rxns) and separating by commas. However, relying on this will prevent updates to their GPRs from being added to the model.
	# rxns_to_skip.update(set(df_enz_rxns.rxns.str.split(',').sum()))
	# make enz_rxn_dict from df_enz_rxns, with 'enz' as keys and 'rxns' and 'protein_stoich' as values
	for index, row in df_enz_rxns.iterrows():
		enz_rxn_dict[row['enz']] = {'rxns': sorted(list(dict.fromkeys(row['rxns'].split(',')))),
										'protein_stoich': {prot.split(':')[0]: float(prot.split(':')[1]) for prot in row['protein_stoich'].split(',')}}
		if not pd.isna(row[mw]):
			enz_rxn_dict[row['enz']][mw] = row[mw]
except:
	df_enz_rxns = pd.DataFrame(columns=['enz','rxns','protein_stoich',mw])
# add dict of protein_stoich to enz_rxn_dict, with each protein as a key and its stoichiometry as the value

# find all unique GPRs in model.reactions, and their associated reactions
for rxn in model.reactions:
	# print(rxn.id, rxn.gene_reaction_rule)
	if rxn.id in rxns_to_skip:
		continue
	if rxn.gene_reaction_rule not in spont_GPRs + ['']:
		if rxn.gene_reaction_rule in GPR_enz_dict.keys():
			# add rxn to corresponding enz in enz_rxn_dict
			enz_ids = GPR_enz_dict[rxn.gene_reaction_rule]
			for enz_id in enz_ids:
				enz_rxn_dict[enz_id]['rxns'].append(rxn.id)
				rxn_updates[rxn.id].setdefault('enz',enz_id)
		else:
			GPR_enz_dict[rxn.gene_reaction_rule] = set()
			enzs = sorted(find_true_combinations(rxn.gene_reaction_rule, use_knockout=True, variables=[g.id for g in rxn.genes]), key=lambda x: sorted(x.keys()))
			for enz in enzs:
				# print('\t',enz)
				enz_found = None
				# default: 1 copy of each protein is used
				# prot_stoich = ','.join([gene+':1' for gene in sorted(enz.keys()) if enz[gene]])
				prot_stoich = {gene:1 for gene in sorted(enz.keys()) if enz[gene]}
				# check if any enzymes with the same stoichiometry are already in enz_rxn_dict
				enz_id = ''.join(sorted(prot_stoich.keys()))

				for old_enz_id in enz_rxn_dict:
					# print(enz_id,enz_rxn_dict[enz_id])
					# automatically assumes enzymes are the same if they have the same proteins, regardless of order/count
					if sorted(enz_rxn_dict[old_enz_id]['protein_stoich'].keys()) == sorted(prot_stoich.keys()):
						enz_rxn_dict[old_enz_id]['rxns'].append(rxn.id)
						enz_found = old_enz_id
						break
				if not enz_found:
					# enz_rxn_dict[rxn.id] = enz
					enz_rxn_dict[enz_id] = {'rxns':[rxn.id],
											'protein_stoich':prot_stoich}
					rxn_updates[rxn.id].setdefault('enz',enz_id)
					GPR_enz_dict[rxn.gene_reaction_rule].add(enz_id)
				else:
					GPR_enz_dict[rxn.gene_reaction_rule].add(enz_found)
	else:
		# add to spont_rxn_dict under its GPR as a list of rxn IDs, if it is not already there
		spont_rxn_dict[rxn.gene_reaction_rule] = spont_rxn_dict.get(rxn.gene_reaction_rule, {'rxns':[],'protein_stoich':{'zeroCost':1}})
		spont_rxn_dict[rxn.gene_reaction_rule]['rxns'].append(rxn.id)
		rxn_updates[rxn.id].setdefault('gene_reaction_rule',rxn.gene_reaction_rule)
		# spont_rxn_dict[rxn.gene_reaction_rule] = spont_rxn_dict.get(rxn.gene_reaction_rule, [rxn.id])
		# spont_rxn_dict[rxn.gene_reaction_rule] = rxn.id
					
# give each enz in enz_rxn_dict a row in df_enz_rxns
new_rows = []
for enz in enz_rxn_dict:
	# only add enzymes that are not already in df_enz_rxns
	if df_enz_rxns[df_enz_rxns.enz == enz].empty:
		# calculate MW of each enzyme based on its protein stoichiometry
		if mw in enz_rxn_dict[enz] and enz_rxn_dict[enz][mw]:
			enz_mw = enz_rxn_dict[enz][mw]
		else:
			enz_mw = 0
			for prot in enz_rxn_dict[enz]['protein_stoich']:
				pro_mw = df_pro.loc[prot,mw] if prot in df_pro.index else 0
				# check in gene_src column
				if pro_mw == 0:
					if prot in df_pro.gene_src.to_list():
						# print(prot,df_pro.loc[df_pro.gene_src == prot,mw])
						# if there are multiple proteins with the same gene_src, check if their MW is the same
						# if not, print a warning
						# pick the first one
						pro_match = df_pro.loc[df_pro.gene_src == prot,mw].to_list()
						if df_pro.loc[df_pro.gene_src == prot,mw].nunique() > 1:
							print(f'Warning: {prot} has multiple MWs in df_pro')
						pro_mw = pro_match[0]
					else:
						print(f'Warning: {prot} not found in df_pro')
				enz_mw += pro_mw*enz_rxn_dict[enz]['protein_stoich'][prot]
		new_rows.append({'enz':enz,'rxns':','.join(enz_rxn_dict[enz]['rxns']),
						'protein_stoich':','.join([prot+':'+str(enz_rxn_dict[enz]['protein_stoich'][prot]) for prot in enz_rxn_dict[enz]['protein_stoich']]),
						mw:enz_mw,
						'status':'automatically added'})
df_enz_rxns = pd.concat([df_enz_rxns, pd.DataFrame(new_rows)], sort=False, ignore_index=True)
# sort by id, MW, and then by rxns
df_enz_rxns = df_enz_rxns.sort_values(by=['rxns',mw,'enz'])
# save automatically updated df_enz_rxns as separate file
df_enz_rxns.to_csv('./model/ENZYME_stoich.tsv', sep='\t', index=False)
# Out:
# Warning: SPONT not found in df_pro
# Warning: TRUE not found in df_pro
# Warning: TRUE not found in df_pro
# /var/folders/fx/q_x2rm651s91fj2m6_tb19pxvpxbmb/T/ipykernel_64752/1784060244.py:98: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_enz_rxns = pd.concat([df_enz_rxns, pd.DataFrame(new_rows)], sort=False, ignore_index=True)

# %%
# check if all rxns in model are accounted for in df_enz_rxns, and if they have been automatically updated
# make a list of all rxns in df_enz_rxns
enz_rxns = []
for index, row in df_enz_rxns.iterrows():
	enz_rxns += row['rxns'].split(',')
enz_rxns = sorted(list(dict.fromkeys(enz_rxns)))
# check if all rxns in model are in enz_rxns
missing_rxns = []
for rxn in model.reactions:
	if rxn.id not in rxns_not_needing_enzymes and rxn.id not in enz_rxns and rxn.id not in whole_biomass_rxns and rxn.gene_reaction_rule not in spont_rxn_dict.keys():
		missing_rxns.append(rxn.id)
if len(missing_rxns) > 0:
	print(f'Warning: the following reactions are not accounted for in df_enz_rxns:')
	for rxn in missing_rxns:
		print(rxn)
# remove rxns from rxn_updates if their value is {}
for rxn in rxn_updates.copy():
	if not rxn_updates[rxn]:
		del rxn_updates[rxn]
	else:
		print(f'Updating {rxn} with {rxn_updates[rxn]}')
# if rxn_updates isn't empty, print a warning
# if len(rxn_updates) > 0:
# 	raise ValueError(f'Warning: the following reactions have been automatically updated:\n{rxn_updates}')
# Out:
# Updating 12AMANTF_g with {'enz': 'rt2093'}
# Updating 13BDGLUCANt_c_en with {'gene_reaction_rule': ''}
# Updating 13BGH_e with {'enz': 'rt5185'}
# Updating 13GS_c with {'enz': 'rt7616'}
# Updating 14BMANTF_c with {'enz': 'rt6298'}
# Updating 14DMLANOSTt_c_e with {'gene_reaction_rule': ''}
# Updating 16GS_c with {'enz': 'rt0150'}
# Updating 1AGPCt_l_rm with {'gene_reaction_rule': ''}
# Updating 1AGPEt_l_rm with {'gene_reaction_rule': ''}
# Updating 1MLCLAT_mm with {'enz': 'rt8106'}
# Updating 2DDA7Pt_c_m with {'gene_reaction_rule': ''}
# Updating 2DHPt_c_m with {'gene_reaction_rule': ''}
# Updating 2DOXG6PP_c with {'enz': 'rt5045'}
# Updating 2MBACt_c_e with {'gene_reaction_rule': ''}
# Updating 2MBALDt_c_e with {'gene_reaction_rule': ''}
# Updating 2MBALDt_c_m with {'gene_reaction_rule': ''}
# Updating 2MBTOHt_c_e with {'gene_reaction_rule': ''}
# Updating 2MBTOHt_c_m with {'gene_reaction_rule': ''}
# Updating 2OBUTt_c_m with {'gene_reaction_rule': ''}
# Updating 2OGMAH_c with {'enz': 'rt6557'}
# Updating 2OSUCAH_c with {'enz': 'rt6557'}
# Updating 2OXOADPt_c_m with {'enz': 'rt2267'}
# Updating 2PHETOHt_c_e with {'gene_reaction_rule': ''}
# Updating 2PHETOHt_c_m with {'gene_reaction_rule': ''}
# Updating 3C3HMPt_c_e with {'gene_reaction_rule': ''}
# Updating 3C3HMPt_c_m with {'gene_reaction_rule': ''}
# Updating 3C4MOPt_c_m with {'gene_reaction_rule': ''}
# Updating 3DHSKD_c with {'enz': 'rt3472'}
# Updating 3DSPHR_r with {'enz': 'rt1611'}
# Updating 3HACD200_rm with {'enz': 'rt2309'}
# Updating 3HACD220_rm with {'enz': 'rt2309'}
# Updating 3HACD240_rm with {'enz': 'rt2309'}
# Updating 3HACD260_rm with {'enz': 'rt2309'}
# Updating 3HAD100_c with {'enz': 'rt0302'}
# Updating 3HAD120_c with {'enz': 'rt0302'}
# Updating 3HAD140_c with {'enz': 'rt0302'}
# Updating 3HAD160_c with {'enz': 'rt0302'}
# Updating 3HAD180_c with {'enz': 'rt0302'}
# Updating 3HAD40_c with {'enz': 'rt0302'}
# Updating 3HAD40_m with {'enz': 'rt7207'}
# Updating 3HAD60_c with {'enz': 'rt0302'}
# Updating 3HAD60_m with {'enz': 'rt7207'}
# Updating 3HAD80_c with {'enz': 'rt0302'}
# Updating 3HAD80_m with {'enz': 'rt7207'}
# Updating 3HAO_c with {'enz': 'rt0234'}
# Updating 3HBHYOX_c with {'enz': 'rt5813'}
# Updating 3HBRDH_c with {'enz': 'rt4427'}
# Updating 3HCINNMH_c with {'enz': 'rt6518'}
# Updating 3HPPPNH_c with {'enz': 'rt6518'}
# Updating 3HXPHBt_c_m with {'gene_reaction_rule': ''}
# Updating 3INDACNLAH_c with {'enz': 'rt4042'}
# Updating 3IPM3MT_c with {'enz': 'rt6691'}
# Updating 3MBALDt_c_e with {'gene_reaction_rule': ''}
# Updating 3MBALDt_c_m with {'gene_reaction_rule': ''}
# Updating 3MLCLAT_mm with {'enz': 'rt8106'}
# Updating 3MOBDC_c with {'enz': 'rt7423'}
# Updating 3MOBR_m with {'enz': 'rt4198rt7068'}
# Updating 3MOPDC_c with {'enz': 'rt7423'}
# Updating 3MOPR_m with {'enz': 'rt4198'}
# Updating 3MOPt_c_e with {'gene_reaction_rule': ''}
# Updating 3NP4H5MOBCL_m with {'gene_reaction_rule': 'UNKNOWN'}
# Updating 3NPDHBZH_m with {'enz': 'rt7829'}
# Updating 3NPDHMT_m with {'enz': 'rt3097'}
# Updating 3OACE200_rm with {'enz': 'rt2975'}
# Updating 3OACE220_rm with {'enz': 'rt8287'}
# Updating 3OACE240_rm with {'enz': 'rt8287'}
# Updating 3OACE260_rm with {'enz': 'rt8287'}
# Updating 3OACR200_rm with {'enz': 'rt8327'}
# Updating 3OACR220_rm with {'enz': 'rt8327'}
# Updating 3OACR240_rm with {'enz': 'rt8327'}
# Updating 3OACR260_rm with {'enz': 'rt8327'}
# Updating 3OADPCOAT_m with {'enz': 'rt4722'}
# Updating 3OAR100_c with {'enz': 'rt2190'}
# Updating 3OAR120_c with {'enz': 'rt1363'}
# Updating 3OAR140_c with {'enz': 'rt1363'}
# Updating 3OAR160_c with {'enz': 'rt1363'}
# Updating 3OAR180_c with {'enz': 'rt1363'}
# Updating 3OAR40_c with {'enz': 'rt1363'}
# Updating 3OAR40_m with {'enz': 'rt1622'}
# Updating 3OAR60_c with {'enz': 'rt1363'}
# Updating 3OAR60_m with {'enz': 'rt1622'}
# Updating 3OAR80_c with {'enz': 'rt1363'}
# Updating 3OAR80_m with {'enz': 'rt1622'}
# Updating 3OAS120_c with {'enz': 'rt0409'}
# Updating 3OAS140_c with {'enz': 'rt0409'}
# Updating 3OAS160_c with {'enz': 'rt0409'}
# Updating 3OAS180_c with {'enz': 'rt0409'}
# Updating 3OAS40_c with {'enz': 'rt0409'}
# Updating 3OAS60_c with {'enz': 'rt0409'}
# Updating 3OAS80_c with {'enz': 'rt0409'}
# Updating 4ABUTNt_c_m with {'gene_reaction_rule': ''}
# Updating 4ABUTt_c_m with {'gene_reaction_rule': ''}
# Updating 4ABUTtps_e with {'enz': 'rt4390'}
# Updating 4ABZt_c_e with {'gene_reaction_rule': ''}
# Updating 4ABZt_c_m with {'gene_reaction_rule': ''}
# Updating 4AMPMS_c with {'enz': 'rt2779'}
# Updating 4CMCOAL_c with {'enz': 'rt8267'}
# Updating 4CMCOAL_x with {'enz': 'rt3465'}
# Updating 4DPMIPPH_c with {'enz': 'rt1973'}
# Updating 4H2OGLTt_c_m with {'gene_reaction_rule': ''}
# Updating 4H2OGLTt_c_x with {'gene_reaction_rule': ''}
# Updating 4HBZCOAS_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating 4HBZF_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating 4HBZNPT_m with {'enz': 'rt6869'}
# Updating 4HBZt_c_m with {'gene_reaction_rule': ''}
# Updating 4HGLSD_m with {'enz': 'rt0201'}
# Updating 4HPEOR_c with {'gene_reaction_rule': ''}
# Updating 4HPLH_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating 4HPPCL_c with {'gene_reaction_rule': ''}
# Updating 4HPPR_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating 4HTHRS_c with {'enz': 'rt1374'}
# Updating 4MOPR_m with {'enz': 'rt4198'}
# Updating 5AOPt_c_m with {'gene_reaction_rule': ''}
# Updating 5FTHFt_c_e with {'gene_reaction_rule': ''}
# Updating 6DPMIPPH_c with {'enz': 'rt1395'}
# Updating AACTOOR_c with {'gene_reaction_rule': ''}
# Updating AASADy_c with {'enz': 'rt1127rt1852'}
# Updating AATA_c with {'enz': 'rt7471'}
# Updating ABTA_c with {'enz': 'rt7537'}
# Updating ABTD2Dx_c with {'enz': 'rt1622'}
# Updating ABTD2Dy_c with {'enz': 'rt8084'}
# Updating ABTD4Dx_c with {'enz': 'rt0620'}
# Updating ABTD4Dy_c with {'enz': 'rt8084'}
# Updating ABTDt_c_e with {'gene_reaction_rule': ''}
# Updating ABTLD_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating ABTt_c_e with {'enz': 'rt8486'}
# Updating ABUTD_m with {'enz': 'rt2756'}
# Updating ACACT100i_m with {'enz': 'rt0517'}
# Updating ACACT100i_x with {'enz': 'rt6860'}
# Updating ACACT101ei_x with {'enz': 'rt5445'}
# Updating ACACT120i_m with {'enz': 'rt0517'}
# Updating ACACT120i_x with {'enz': 'rt5445'}
# Updating ACACT121ai_m with {'enz': 'rt0517'}
# Updating ACACT121ai_x with {'enz': 'rt5445'}
# Updating ACACT121di_x with {'enz': 'rt5445'}
# Updating ACACT122ei_x with {'enz': 'rt5445'}
# Updating ACACT140i_m with {'enz': 'rt0517'}
# Updating ACACT140i_x with {'enz': 'rt5445'}
# Updating ACACT141ai_m with {'enz': 'rt0517'}
# Updating ACACT141ai_x with {'enz': 'rt5445'}
# Updating ACACT141bi_m with {'enz': 'rt0517'}
# Updating ACACT141bi_x with {'enz': 'rt5445'}
# Updating ACACT142i_x with {'enz': 'rt5445'}
# Updating ACACT143i_x with {'enz': 'rt5445'}
# Updating ACACT160i_m with {'enz': 'rt0517'}
# Updating ACACT160i_x with {'enz': 'rt5445'}
# Updating ACACT161ai_m with {'enz': 'rt0517'}
# Updating ACACT161ai_x with {'enz': 'rt5445'}
# Updating ACACT161bi_m with {'enz': 'rt0517'}
# Updating ACACT161bi_x with {'enz': 'rt5445'}
# Updating ACACT162i_x with {'enz': 'rt5445'}
# Updating ACACT163i_x with {'enz': 'rt5445'}
# Updating ACACT180i_m with {'enz': 'rt0517'}
# Updating ACACT180i_x with {'enz': 'rt5445'}
# Updating ACACT181ai_m with {'enz': 'rt0517'}
# Updating ACACT181ai_x with {'enz': 'rt5445'}
# Updating ACACT182i_x with {'enz': 'rt5445'}
# Updating ACACT183i_x with {'enz': 'rt5445'}
# Updating ACACT200i_m with {'enz': 'rt0517'}
# Updating ACACT200i_x with {'enz': 'rt5445'}
# Updating ACACT220i_m with {'enz': 'rt0517'}
# Updating ACACT220i_x with {'enz': 'rt5445'}
# Updating ACACT240i_m with {'enz': 'rt0517'}
# Updating ACACT240i_x with {'enz': 'rt5445'}
# Updating ACACT260i_m with {'enz': 'rt0517'}
# Updating ACACT260i_x with {'enz': 'rt5445'}
# Updating ACACT40i_m with {'enz': 'rt0517'}
# Updating ACACT40i_x with {'enz': 'rt5445'}
# Updating ACACT40ir_c with {'enz': 'rt0310'}
# Updating ACACT60i_m with {'enz': 'rt0517'}
# Updating ACACT60i_x with {'enz': 'rt5445'}
# Updating ACACT80i_m with {'enz': 'rt0517'}
# Updating ACACT80i_x with {'enz': 'rt5445'}
# Updating ACALDCD_c with {'enz': 'rt7423'}
# Updating ACALDt_c_e with {'gene_reaction_rule': ''}
# Updating ACALDt_c_m with {'gene_reaction_rule': ''}
# Updating ACCOAC_c with {'enz': 'rt0271rt8036'}
# Updating ACCOATsucac_m with {'enz': 'rt5429'}
# Updating ACCOATsucpp_m with {'enz': 'rt5429'}
# Updating ACCOAt_c_n with {'gene_reaction_rule': ''}
# Updating ACCOAt_c_r with {'enz': 'rt2578'}
# Updating ACEST1_m with {'enz': 'rt1634'}
# Updating ACEST1_x with {'enz': 'rt0018rt2393'}
# Updating ACGAM6PS_c with {'enz': 'rt4107'}
# Updating ACGAM6S1_r with {'enz': 'rt5121'}
# Updating ACGAM6S2_r with {'enz': 'rt5121'}
# Updating ACGAMPM_c with {'enz': 'rt4597'}
# Updating ACGK_m with {'enz': 'rt1009'}
# Updating ACGS_m with {'enz': 'rt7899'}
# Updating ACHAH_c with {'enz': 'rt3378'}
# Updating ACHAH_e with {'enz': 'rt1203'}
# Updating ACHBS_m with {'enz': 'rt7317'}
# Updating ACHLE1_c with {'enz': 'rt6872'}
# Updating ACHLE2_c with {'enz': 'rt6872'}
# Updating ACHLE3_c with {'enz': 'rt6872'}
# Updating ACITL_c with {'enz': 'rt1358'}
# Updating ACKr_c with {'enz': 'rt5015'}
# Updating ACLS_m with {'enz': 'rt7317'}
# Updating ACOAD100f_m with {'enz': 'rt4202'}
# Updating ACOAD100f_x with {'enz': 'rt0595'}
# Updating ACOAD101df_x with {'enz': 'rt0595'}
# Updating ACOAD102ef_x with {'enz': 'rt0595'}
# Updating ACOAD120f_m with {'enz': 'rt4202'}
# Updating ACOAD120f_x with {'enz': 'rt0595'}
# Updating ACOAD121af_x with {'enz': 'rt0595'}
# Updating ACOAD140f_x with {'enz': 'rt0595'}
# Updating ACOAD141af_x with {'enz': 'rt0595'}
# Updating ACOAD141bf_x with {'enz': 'rt0595'}
# Updating ACOAD142f_x with {'enz': 'rt0595'}
# Updating ACOAD143f_x with {'enz': 'rt0595'}
# Updating ACOAD160f_x with {'enz': 'rt0595'}
# Updating ACOAD161af_x with {'enz': 'rt0595'}
# Updating ACOAD161bf_x with {'enz': 'rt0595'}
# Updating ACOAD162f_x with {'enz': 'rt0595'}
# Updating ACOAD163f_x with {'enz': 'rt0595'}
# Updating ACOAD180f_x with {'enz': 'rt0595'}
# Updating ACOAD181af_x with {'enz': 'rt0595'}
# Updating ACOAD182f_x with {'enz': 'rt0595'}
# Updating ACOAD183f_x with {'enz': 'rt0595'}
# Updating ACOAD40f_m with {'enz': 'rt5702'}
# Updating ACOAD40f_x with {'enz': 'rt0595'}
# Updating ACOAD60f_m with {'enz': 'rt5702'}
# Updating ACOAD60f_x with {'enz': 'rt0595'}
# Updating ACOAD80f_m with {'enz': 'rt4202'}
# Updating ACOAD80f_x with {'enz': 'rt0595'}
# Updating ACOAD82ef_x with {'enz': 'rt0595'}
# Updating ACOADS160_rm with {'enz': 'rt1362'}
# Updating ACOADS180_rm with {'enz': 'rt1362'}
# Updating ACOADS181_rm with {'enz': 'rt0477'}
# Updating ACOADS182_3_rm with {'enz': 'rt8487'}
# Updating ACOADS182_rm with {'enz': 'rt0477'}
# Updating ACOADm30f_m with {'enz': 'rt5702'}
# Updating ACOADm40f_m with {'enz': 'rt5702'}
# Updating ACOADm50f_m with {'enz': 'rt1644'}
# Updating ACOAO100_x with {'enz': 'rt4374'}
# Updating ACOAO101d_x with {'enz': 'rt4384'}
# Updating ACOAO102e_x with {'enz': 'rt4384'}
# Updating ACOAO120_x with {'enz': 'rt4384'}
# Updating ACOAO121a_x with {'enz': 'rt4384'}
# Updating ACOAO140_x with {'enz': 'rt4384'}
# Updating ACOAO141a_x with {'enz': 'rt4384'}
# Updating ACOAO141b_x with {'enz': 'rt4384'}
# Updating ACOAO142_x with {'enz': 'rt4384'}
# Updating ACOAO143_x with {'enz': 'rt4384'}
# Updating ACOAO160_x with {'enz': 'rt4384'}
# Updating ACOAO161a_x with {'enz': 'rt4384'}
# Updating ACOAO161b_x with {'enz': 'rt4384'}
# Updating ACOAO162_x with {'enz': 'rt4384'}
# Updating ACOAO163_x with {'enz': 'rt4384'}
# Updating ACOAO180_x with {'enz': 'rt4384'}
# Updating ACOAO181a_x with {'enz': 'rt4384'}
# Updating ACOAO182_x with {'enz': 'rt4384'}
# Updating ACOAO183_x with {'enz': 'rt4384'}
# Updating ACOAO200_x with {'enz': 'rt4384'}
# Updating ACOAO220_x with {'enz': 'rt4384'}
# Updating ACOAO240_x with {'enz': 'rt4384'}
# Updating ACOAO260_x with {'enz': 'rt4384'}
# Updating ACOAO40_x with {'enz': 'rt4384'}
# Updating ACOAO60_x with {'enz': 'rt4384'}
# Updating ACOAO80_x with {'enz': 'rt4384'}
# Updating ACOAO82e_x with {'enz': 'rt4384'}
# Updating ACOATA_c with {'enz': 'rt0302'}
# Updating ACOATA_m with {'enz': 'rt5893'}
# Updating ACONIs_c with {'gene_reaction_rule': ''}
# Updating ACONIs_m with {'gene_reaction_rule': ''}
# Updating ACONMT_c with {'enz': 'rt6691'}
# Updating ACONT2_m with {'enz': 'rt4274'}
# Updating ACONTa_m with {'enz': 'rt6232'}
# Updating ACONTb_m with {'enz': 'rt3256'}
# Updating ACOTAi_m with {'enz': 'rt6510'}
# Updating ACP1_e with {'enz': 'rt1163'}
# Updating ACPCS_c with {'enz': 'rt0245'}
# Updating ACRNAH_x with {'enz': 'rt5418'}
# Updating ACRNt_c_m with {'gene_reaction_rule': ''}
# Updating ACRNt_c_x with {'gene_reaction_rule': ''}
# Updating ACS_c with {'enz': 'rt7532'}
# Updating ACS_n with {'enz': 'rt7532'}
# Updating ACt_c_e with {'enz': 'rt7285'}
# Updating ACt_c_m with {'enz': 'rt5456'}
# Updating ACt_c_n with {'gene_reaction_rule': ''}
# Updating ADA_c with {'enz': 'rt8364'}
# Updating ADCL_c with {'enz': 'rt4108'}
# Updating ADCS_c with {'enz': 'rt5301'}
# Updating ADD_c with {'enz': 'rt3300'}
# Updating ADEt_c_m with {'gene_reaction_rule': ''}
# Updating ADEtps_e with {'enz': 'rt6190'}
# Updating ADK1_c with {'enz': 'rt7128'}
# Updating ADK1_m with {'enz': 'rt6761'}
# Updating ADK3_m with {'enz': 'rt7128'}
# Updating ADMDC_c with {'enz': 'rt2849'}
# Updating ADNCYC_c with {'enz': 'rt4919'}
# Updating ADNK1_c with {'enz': 'rt0017'}
# Updating ADNtps_e with {'enz': 'rt5601'}
# Updating ADPATPt_c_m with {'enz': 'rt4336'}
# Updating ADPATPt_c_x with {'enz': 'rt7777'}
# Updating ADPRDP_m with {'enz': 'rt8143'}
# Updating ADPT_c with {'enz': 'rt7825'}
# Updating ADPh_c with {'gene_reaction_rule': 'SPONT'}
# Updating ADPh_m with {'gene_reaction_rule': 'SPONT'}
# Updating ADPt_c_en with {'gene_reaction_rule': ''}
# Updating ADPt_c_gm with {'gene_reaction_rule': ''}
# Updating ADPt_c_n with {'gene_reaction_rule': ''}
# Updating ADPt_c_r with {'gene_reaction_rule': ''}
# Updating ADPt_c_vm with {'gene_reaction_rule': ''}
# Updating ADSK_c with {'enz': 'rt0341'}
# Updating ADSL1r_c with {'enz': 'rt7437'}
# Updating ADSL2i_c with {'enz': 'rt7437'}
# Updating ADSS_c with {'enz': 'rt3802'}
# Updating AEPI1_c with {'enz': 'rt0136'}
# Updating AEPI2_c with {'enz': 'rt0136'}
# Updating AFAT_c with {'enz': 'rt3174'}
# Updating AFLTXNB1S_c with {'enz': 'rt2689'}
# Updating AFLTXNB2S_c with {'enz': 'rt2689'}
# Updating AGMT_e with {'enz': 'rt1772'}
# Updating AGNPR_l with {'enz': 'rt7207'}
# Updating AGNPR_rm with {'enz': 'rt7207'}
# Updating AGPAT_l with {'enz': 'rt2059'}
# Updating AGPAT_rm with {'enz': 'rt7662'}
# Updating AGPRi_m with {'enz': 'rt1009'}
# Updating AGTi_c with {'enz': 'rt0451'}
# Updating AHCYSt_c_m with {'gene_reaction_rule': ''}
# Updating AHCYSt_c_rm with {'gene_reaction_rule': ''}
# Updating AHCi_c with {'enz': 'rt4544'}
# Updating AHGDf_m with {'enz': 'rt1883'}
# Updating AHMMPS4_c with {'enz': 'rt2779'}
# Updating AHSERL2_c with {'enz': 'rt8250'}
# Updating AHSERL_c with {'enz': 'rt8250'}
# Updating AICART_c with {'enz': 'rt4053'}
# Updating AIRC1_c with {'enz': 'rt3764'}
# Updating AKGCITta_m with {'enz': 'rt8378'}
# Updating AKGDH_m with {'enz': 'rt1639rt1672rt3748'}
# Updating AKGMALta_m with {'enz': 'rt2267'}
# Updating AKGt_c_e with {'gene_reaction_rule': ''}
# Updating AKGt_c_n with {'gene_reaction_rule': ''}
# Updating AKGt_c_x with {'gene_reaction_rule': ''}
# Updating AKP1_c with {'enz': 'rt5041'}
# Updating ALAS_m with {'enz': 'rt0309'}
# Updating ALATA_L_m with {'enz': 'rt1267'}
# Updating ALATRS_c with {'enz': 'rt3605'}
# Updating ALAt_c_m with {'gene_reaction_rule': ''}
# Updating ALAtps_e with {'enz': 'rt5861'}
# Updating ALCD19y_c with {'enz': 'rt3514'}
# Updating ALCD22xi_c with {'enz': 'rt8149'}
# Updating ALCD22xi_m with {'enz': 'rt3939'}
# Updating ALCD22yi_c with {'enz': 'rt4416'}
# Updating ALCD23xi_c with {'enz': 'rt8149'}
# Updating ALCD23xi_m with {'enz': 'rt3939'}
# Updating ALCD24xi_c with {'enz': 'rt8149'}
# Updating ALCD24xi_m with {'enz': 'rt3939'}
# Updating ALCD24yi_c with {'enz': 'rt5194'}
# Updating ALCD25xi_c with {'enz': 'rt8149'}
# Updating ALCD25xi_m with {'enz': 'rt3939'}
# Updating ALCD25yi_c with {'enz': 'rt5194'}
# Updating ALCD26xi_c with {'enz': 'rt8149'}
# Updating ALCD26xi_m with {'enz': 'rt3939'}
# Updating ALCD2i1_c with {'enz': 'rt3282'}
# Updating ALCD2i2_c with {'enz': 'rt7070'}
# Updating ALCD2i2_m with {'enz': 'rt3939'}
# Updating ALDD20x_m with {'enz': 'rt2756'}
# Updating ALDD20y_c with {'enz': 'rt7041'}
# Updating ALDD20y_m with {'enz': 'rt3674'}
# Updating ALDD22x_c with {'enz': 'rt7955'}
# Updating ALDD2x_c with {'enz': 'rt2756'}
# Updating ALDD2y_c with {'enz': 'rt3674'}
# Updating ALLTN_c with {'enz': 'rt3516'}
# Updating ALLTNt_c with {'enz': 'rt4534'}
# Updating ALLTTt_c with {'enz': 'rt6702'}
# Updating ALPHNH_c with {'enz': 'rt0958'}
# Updating AMAOTr_c with {'enz': 'rt4363'}
# Updating AMETt_c_e with {'gene_reaction_rule': ''}
# Updating AMETt_c_m with {'enz': 'rt3664'}
# Updating AMETt_c_rm with {'gene_reaction_rule': ''}
# Updating AMID_c with {'enz': 'rt3257'}
# Updating AMPATPt_c_x with {'enz': 'rt7777'}
# Updating AMPDA_c with {'enz': 'rt3101'}
# Updating AMPt_c_l with {'gene_reaction_rule': ''}
# Updating AMPt_c_n with {'gene_reaction_rule': ''}
# Updating AMPt_c_rm with {'gene_reaction_rule': ''}
# Updating ANNAT_c with {'enz': 'rt7589'}
# Updating ANPRT_c with {'enz': 'rt1532'}
# Updating ANS_c with {'enz': 'rt6741rt8196'}
# Updating AOBUTDs_c with {'gene_reaction_rule': ''}
# Updating AOXS_c with {'enz': 'rt4368'}
# Updating AP4AH_c with {'enz': 'rt0084'}
# Updating ARAB14LO_c with {'enz': 'rt5365'}
# Updating ARAB14LO_x with {'enz': 'rt2122'}
# Updating ARAB1Dx_c with {'enz': 'rt8345'}
# Updating ARABDt_c with {'gene_reaction_rule': ''}
# Updating ARABLt_c with {'gene_reaction_rule': ''}
# Updating ARABRy_c with {'enz': 'rt5845'}
# Updating ARACHt_c_e with {'enz': 'rt1544rt2799'}
# Updating ARACHt_c_rm with {'gene_reaction_rule': ''}
# Updating ARAI2_c with {'enz': 'rt6112'}
# Updating ARAK_c with {'enz': 'rt4526'}
# Updating ARGN_c with {'enz': 'rt7813'}
# Updating ARGSL_c with {'enz': 'rt3236'}
# Updating ARGSS_c with {'enz': 'rt7828'}
# Updating ARGTRS_c with {'enz': 'rt1711'}
# Updating ARGtpa_v with {'enz': 'rt0111'}
# Updating ARGtps_e with {'enz': 'rt1689'}
# Updating ARGtps_m with {'gene_reaction_rule': ''}
# Updating ARMT_c with {'enz': 'rt1648'}
# Updating AROHL_c with {'enz': 'rt5827'}
# Updating ARSO4H_c with {'enz': 'rt6899'}
# Updating ASAD_c with {'enz': 'rt1962'}
# Updating ASCBOX_c with {'enz': 'rt5489'}
# Updating ASNN_e with {'enz': 'rt1675'}
# Updating ASNS1_c with {'enz': 'rt6769'}
# Updating ASNTRS_c with {'enz': 'rt0799'}
# Updating ASNTRS_m with {'enz': 'rt3755'}
# Updating ASNt_c_m with {'gene_reaction_rule': ''}
# Updating ASNtpa_v with {'enz': 'rt7819'}
# Updating ASNtps_v with {'enz': 'rt4375'}
# Updating ASPCT_c with {'enz': 'rt8313'}
# Updating ASPGLUt_c_m with {'enz': 'rt8431'}
# Updating ASPGLUt_c_x with {'gene_reaction_rule': ''}
# Updating ASPK_c with {'enz': 'rt6294'}
# Updating ASPTA4_c with {'enz': 'rt1784'}
# Updating ASPTA_c with {'enz': 'rt0568'}
# Updating ASPTA_x with {'enz': 'rt5913'}
# Updating ASPTAi_m with {'enz': 'rt5562'}
# Updating ASPTRS_c with {'enz': 'rt5890'}
# Updating ASPtps_v with {'enz': 'rt0398'}
# Updating ATAH_c with {'enz': 'rt6356'}
# Updating ATHRDHr_c with {'enz': 'rt1844'}
# Updating ATPASEP2e_c with {'enz': 'rt0602'}
# Updating ATPASEV_v with {'enz': 'rt0842rt1254rt1380rt2434rt2657rt2684rt2696rt2749rt3035rt6603rt6941rt6983rt7595rt8029'}
# Updating ATPATF1_c with {'enz': 'rt5328'}
# Updating ATPHs_c with {'gene_reaction_rule': ''}
# Updating ATPM_c with {'gene_reaction_rule': ''}
# Updating ATPPRT_c with {'enz': 'rt1520'}
# Updating ATPS_m with {'enz': 'rt0712rt2306rt3590rt3599rt5056rt5391rt5474rt6418rt6544rt7221rt7991rtmATP6rtmATP8rtmATP9'}
# Updating ATPt_c_en with {'gene_reaction_rule': ''}
# Updating ATPt_c_gm with {'gene_reaction_rule': ''}
# Updating ATPt_c_l with {'gene_reaction_rule': ''}
# Updating ATPt_c_n with {'gene_reaction_rule': ''}
# Updating ATPt_c_r with {'gene_reaction_rule': ''}
# Updating ATPt_c_rm with {'gene_reaction_rule': ''}
# Updating ATPt_c_vm with {'gene_reaction_rule': ''}
# Updating AVNORy_c with {'enz': 'rt7877'}
# Updating BACCL_c with {'enz': 'rt8036'}
# Updating BBOX_m with {'enz': 'rt6692'}
# Updating BETALDHx_x with {'enz': 'rt2053'}
# Updating BIOMASS_PinheiroEtAl2020 with {'gene_reaction_rule': ''}
# Updating BIOMASS_xyl_hybrid with {'gene_reaction_rule': ''}
# Updating BPNT_c with {'enz': 'rt2305'}
# Updating BTDDH_c with {'enz': 'rt5273'}
# Updating BTDt_c_e with {'gene_reaction_rule': ''}
# Updating BTS1_c with {'enz': 'rt7540'}
# Updating BTS1_m with {'enz': 'rt7540'}
# Updating BUTt_c_e with {'gene_reaction_rule': ''}
# Updating BUTt_c_x with {'gene_reaction_rule': ''}
# Updating BZHYOX_c with {'enz': 'rt5813'}
# Updating BZHYOX_r with {'enz': 'rt1936'}
# Updating C14STR_c with {'enz': 'rt0303'}
# Updating C22STDSy_c with {'enz': 'rt3348'}
# Updating C24STR_r with {'enz': 'rt2613'}
# Updating C3STDH1_c with {'enz': 'rt0467'}
# Updating C3STDH2_c with {'enz': 'rt0467'}
# Updating C3STKR1_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating C3STKR2_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating C4STMO1_c with {'enz': 'rt8272'}
# Updating C4STMO2_c with {'enz': 'rt8272'}
# Updating C4STMO3_c with {'enz': 'rt8272'}
# Updating C4STMO4_c with {'enz': 'rt8272'}
# Updating C5STDS_c with {'enz': 'rt0413'}
# Updating C8STI_c with {'enz': 'rt1745'}
# Updating CA2t_c_e with {'gene_reaction_rule': ''}
# Updating CAROL1_c with {'enz': 'rt0221'}
# Updating CAROL2_c with {'enz': 'rt0221'}
# Updating CAROL3_c with {'enz': 'rt0221'}
# Updating CAROMOX1_c with {'enz': 'rt0220'}
# Updating CAROMOX2_c with {'enz': 'rt0220'}
# Updating CATDOX_c with {'enz': 'rt0267'}
# Updating CATOX_e with {'enz': 'rt4763'}
# Updating CAT_c with {'enz': 'rt0986'}
# Updating CAT_x with {'enz': 'rt6937'}
# Updating CBL_c with {'enz': 'rt0391'}
# Updating CBMHL_c with {'enz': 'rt2726'}
# Updating CBPS_c with {'enz': 'rt3934rt4929rt8313'}
# Updating CDPCHOLt_c_rm with {'gene_reaction_rule': ''}
# Updating CDPDAGS_mm with {'enz': 'rt4513'}
# Updating CDPDAGS_rm with {'enz': 'rt4513'}
# Updating CDPEAt_c_rm with {'gene_reaction_rule': ''}
# Updating CDPt_c_n with {'gene_reaction_rule': ''}
# Updating CDPt_c_rm with {'gene_reaction_rule': ''}
# Updating CELLBH_e with {'enz': 'rt8348'}
# Updating CEPHSCOX_x with {'enz': 'rt3508'}
# Updating CERH124A_r with {'enz': 'rt6946'}
# Updating CERH124B_r with {'enz': 'rt1296'}
# Updating CERH126A_r with {'enz': 'rt6946'}
# Updating CERH126B_r with {'enz': 'rt1296'}
# Updating CERH2A24_r with {'enz': 'rt1296'}
# Updating CERH2A26_r with {'enz': 'rt1296'}
# Updating CERH324_r with {'enz': 'rt1296'}
# Updating CERH326_r with {'enz': 'rt1296'}
# Updating CERS124_c with {'enz': 'rt3023'}
# Updating CERS126_c with {'enz': 'rt6800'}
# Updating CERS2A24_r with {'enz': 'rt6800'}
# Updating CERS2A26_r with {'enz': 'rt6800'}
# Updating CERt_g_r with {'gene_reaction_rule': ''}
# Updating CFCOAMT_c with {'enz': 'rt5076'}
# Updating CHITOSNSE_c with {'enz': 'rt2528'}
# Updating CHLPCTD_c with {'enz': 'rt2172'}
# Updating CHLSTI2_c with {'enz': 'rt5191'}
# Updating CHOLD_c with {'enz': 'rt3274'}
# Updating CHOLK_c with {'enz': 'rt7614'}
# Updating CHOLPT_rm with {'enz': 'rt2983'}
# Updating CHOLt_c_en with {'gene_reaction_rule': ''}
# Updating CHOLtps_e with {'enz': 'rt7623'}
# Updating CHORM_c with {'enz': 'rt1336'}
# Updating CHORS_c with {'enz': 'rt5669'}
# Updating CHRPL_c with {'gene_reaction_rule': ''}
# Updating CHTNDA_c with {'enz': 'rt0086'}
# Updating CHTNH_e with {'enz': 'rt6409'}
# Updating CHTNH_v with {'enz': 'rt4284'}
# Updating CHTNS_c with {'enz': 'rt6592'}
# Updating CITCOAL_c with {'enz': 'rt1454'}
# Updating CITICITta_m with {'enz': 'rt2146'}
# Updating CITICTta_x with {'gene_reaction_rule': ''}
# Updating CITMALta_m with {'enz': 'rt2146'}
# Updating CITMALta_x with {'gene_reaction_rule': ''}
# Updating CITt3_m with {'enz': 'rt2146'}
# Updating CITt_c_e with {'gene_reaction_rule': ''}
# Updating CLAH1_mm with {'gene_reaction_rule': 'UNKNOWN'}
# Updating CLAH3_mm with {'gene_reaction_rule': 'UNKNOWN'}
# Updating CLPNS_mm with {'enz': 'rt8047'}
# Updating CLt_c_e with {'enz': 'rt6468'}
# Updating CMBOLHcis_c with {'enz': 'rt6386'}
# Updating CMBOLHtrans_c with {'enz': 'rt6386'}
# Updating CMPA_c with {'enz': 'rt3507'}
# Updating CMPN_c with {'gene_reaction_rule': ''}
# Updating CMPt_c_rm with {'gene_reaction_rule': ''}
# Updating CMPt_m_mm with {'gene_reaction_rule': ''}
# Updating CMUCOC_c with {'enz': 'rt5764'}
# Updating CO2t_c_e with {'gene_reaction_rule': ''}
# Updating CO2t_c_gm with {'gene_reaction_rule': ''}
# Updating CO2t_c_m with {'gene_reaction_rule': ''}
# Updating CO2t_c_mm with {'gene_reaction_rule': ''}
# Updating CO2t_c_n with {'gene_reaction_rule': ''}
# Updating CO2t_c_r with {'gene_reaction_rule': ''}
# Updating CO2t_c_rm with {'gene_reaction_rule': ''}
# Updating CO2t_c_vm with {'gene_reaction_rule': ''}
# Updating CO2t_c_x with {'gene_reaction_rule': ''}
# Updating COAt_c_l with {'gene_reaction_rule': ''}
# Updating COAt_c_m with {'enz': 'rt0548'}
# Updating COAt_c_mm with {'gene_reaction_rule': ''}
# Updating COAt_c_n with {'gene_reaction_rule': ''}
# Updating COAt_c_r with {'gene_reaction_rule': ''}
# Updating COAt_c_rm with {'gene_reaction_rule': ''}
# Updating COAt_c_x with {'gene_reaction_rule': ''}
# Updating COBALT2t_c_e with {'gene_reaction_rule': ''}
# Updating CPLSPNEST_e with {'enz': 'rt3377'}
# Updating CPPPGO_c with {'enz': 'rt5829'}
# Updating CRN100t_c_m with {'enz': 'rt0963'}
# Updating CRN100t_c_x with {'enz': 'rt7415'}
# Updating CRN120t_c_m with {'enz': 'rt0963'}
# Updating CRN120t_c_x with {'enz': 'rt7415'}
# Updating CRN40t_c_m with {'enz': 'rt0963'}
# Updating CRN40t_c_x with {'enz': 'rt7415'}
# Updating CRN60t_c_m with {'enz': 'rt0963'}
# Updating CRN60t_c_x with {'enz': 'rt7415'}
# Updating CRN80t_c_m with {'enz': 'rt0963'}
# Updating CRN80t_c_x with {'enz': 'rt7415'}
# Updating CRNACRNt_c_m with {'enz': 'rt0963'}
# Updating CRNAT100_m with {'enz': 'rt7415'}
# Updating CRNAT100_x with {'enz': 'rt5212'}
# Updating CRNAT120_m with {'enz': 'rt7415'}
# Updating CRNAT120_x with {'enz': 'rt5212'}
# Updating CRNAT40_m with {'enz': 'rt7415'}
# Updating CRNAT40_x with {'enz': 'rt5212'}
# Updating CRNAT60_m with {'enz': 'rt7415'}
# Updating CRNAT60_x with {'enz': 'rt5212'}
# Updating CRNAT80_m with {'enz': 'rt7415'}
# Updating CRNAT80_x with {'enz': 'rt5212'}
# Updating CRNCARt_c_x with {'gene_reaction_rule': ''}
# Updating CRNOAT_m with {'enz': 'rt0947'}
# Updating CRNt_c_m with {'enz': 'rt0963'}
# Updating CRNt_c_x with {'gene_reaction_rule': ''}
# Updating CSND_c with {'enz': 'rt6191'}
# Updating CSNPURt_c_e with {'enz': 'rt6644'}
# Updating CSNtps_e with {'enz': 'rt6190'}
# Updating CS_m with {'enz': 'rt2963'}
# Updating CS_x with {'enz': 'rt0180'}
# Updating CTPCMPt_c_m with {'enz': 'rt4019'}
# Updating CTPS1_c with {'enz': 'rt8107'}
# Updating CTPS2_c with {'enz': 'rt8107'}
# Updating CTPt2_m with {'enz': 'rt4019'}
# Updating CTPt_c_rm with {'gene_reaction_rule': ''}
# Updating CTPt_m_mm with {'gene_reaction_rule': ''}
# Updating CU2t_c_e with {'gene_reaction_rule': 'UNKNOWN'}
# Updating CYSItps_v with {'enz': 'rt6589'}
# Updating CYSS_c with {'enz': 'rt3663'}
# Updating CYSTGL_c with {'enz': 'rt1131'}
# Updating CYSTRS_c with {'enz': 'rt1487'}
# Updating CYSTS_c with {'enz': 'rt7344'}
# Updating CYTDK2_c with {'enz': 'rt0265'}
# Updating CYTD_c with {'enz': 'rt7919'}
# Updating CYTDtps_e with {'enz': 'rt5601'}
# Updating CYTK1_c with {'gene_reaction_rule': ''}
# Updating CYTK2_c with {'gene_reaction_rule': ''}
# Updating DADA_c with {'enz': 'rt8364'}
# Updating DADPt_c_n with {'gene_reaction_rule': ''}
# Updating DADt_c_e with {'gene_reaction_rule': ''}
# Updating DAG3Pabct_c_m with {'enz': 'rt1060'}
# Updating DAGK_rm with {'enz': 'rt1788'}
# Updating DAGL_m with {'enz': 'rt5949'}
# Updating DAGt_c_l with {'gene_reaction_rule': ''}
# Updating DAGt_c_mm with {'gene_reaction_rule': ''}
# Updating DAGt_c_n with {'gene_reaction_rule': ''}
# Updating DAGt_c_r with {'gene_reaction_rule': ''}
# Updating DAGt_c_rm with {'gene_reaction_rule': ''}
# Updating DAGt_gm_rm with {'gene_reaction_rule': ''}
# Updating DANNt_c_e with {'gene_reaction_rule': ''}
# Updating DAO4hpro_x with {'enz': 'rt7626'}
# Updating DAOala_x with {'enz': 'rt7626'}
# Updating DAOarg_x with {'enz': 'rt7626'}
# Updating DAOgly_x with {'enz': 'rt7626'}
# Updating DAOorn_x with {'enz': 'rt7626'}
# Updating DAOpro_x with {'enz': 'rt7626'}
# Updating DB4PS_c with {'enz': 'rt8298'}
# Updating DBTS_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating DCAt_c_e with {'enz': 'rt1544rt2799'}
# Updating DCAt_c_x with {'enz': 'SPONT'}
# Updating DCDPt_c_n with {'gene_reaction_rule': ''}
# Updating DCMPDA_c with {'enz': 'rt0757'}
# Updating DCYTD_c with {'enz': 'rt7919'}
# Updating DCYTt_c_e with {'gene_reaction_rule': ''}
# Updating DDCACOAt_c_l with {'gene_reaction_rule': ''}
# Updating DDCACOAt_c_rm with {'gene_reaction_rule': ''}
# Updating DDCAt_c_e with {'enz': 'rt1544rt2799'}
# Updating DDCAt_c_rm with {'gene_reaction_rule': ''}
# Updating DDCAt_c_x with {'enz': 'rt5693'}
# Updating DDCAt_l_rm with {'gene_reaction_rule': ''}
# Updating DDPA_c with {'enz': 'rt2234'}
# Updating DDPA_m with {'enz': 'rt2234'}
# Updating DECOAI82e_x with {'enz': 'rt3539'}
# Updating DECOAR102d_x with {'enz': 'rt4860'}
# Updating DECOAR103e_x with {'enz': 'rt4860'}
# Updating DECOAR82e_x with {'enz': 'rt4860'}
# Updating DESAT18_2_rm with {'enz': 'rt0477'}
# Updating DGAT_l with {'enz': 'rt8092'}
# Updating DGAT_rm with {'enz': 'rt8092'}
# Updating DGDPt_c_n with {'gene_reaction_rule': ''}
# Updating DGK1_c with {'enz': 'rt3157'}
# Updating DGLCND3H_c with {'enz': 'rt2544'}
# Updating DGLCND5H_c with {'enz': 'rt2544'}
# Updating DGPP_vm with {'enz': 'rt4719'}
# Updating DGSNt_c_e with {'gene_reaction_rule': ''}
# Updating DHAD1_c with {'enz': 'rt6258'}
# Updating DHAD1_m with {'enz': 'rt1321'}
# Updating DHAD2_c with {'enz': 'rt6258'}
# Updating DHAD2_m with {'enz': 'rt1321'}
# Updating DHAK_c with {'enz': 'rt3901'}
# Updating DHAPAT_l with {'enz': 'rt5001'}
# Updating DHAPAT_rm with {'enz': 'rt5001'}
# Updating DHAPt_c_l with {'gene_reaction_rule': ''}
# Updating DHAPt_c_m with {'gene_reaction_rule': ''}
# Updating DHAPt_c_rm with {'gene_reaction_rule': ''}
# Updating DHAPt_c_x with {'gene_reaction_rule': ''}
# Updating DHFRi_c with {'enz': 'rt3791'}
# Updating DHFRi_m with {'enz': 'rt3791'}
# Updating DHFS_1_c with {'enz': 'rt2092'}
# Updating DHFt_c_m with {'gene_reaction_rule': ''}
# Updating DHNPA2i_m with {'enz': 'rt6009'}
# Updating DHNPTt_c_m with {'gene_reaction_rule': ''}
# Updating DHORDfum_c with {'enz': 'rt6498'}
# Updating DHORTS_c with {'enz': 'rt3923'}
# Updating DHPM2_c with {'enz': 'rt3509'}
# Updating DHPPDA2_c with {'enz': 'rt7138'}
# Updating DHPTS_m with {'enz': 'rt6009'}
# Updating DHPTt_c_m with {'gene_reaction_rule': ''}
# Updating DHQS_c with {'enz': 'rt5884'}
# Updating DHQTi_c with {'enz': 'rt2204'}
# Updating DINt_c_e with {'gene_reaction_rule': ''}
# Updating DIPS_c with {'enz': 'rt8137'}
# Updating DKMEOX_c with {'enz': 'rt7962'}
# Updating DKMPPH_c with {'enz': 'rt7962'}
# Updating DMATT_c with {'enz': 'rt4576'}
# Updating DM_5mta_c with {'gene_reaction_rule': ''}
# Updating DM_gcald_c with {'gene_reaction_rule': ''}
# Updating DNADt_c_n with {'gene_reaction_rule': ''}
# Updating DNMPPA_c with {'enz': 'rt6247'}
# Updating DNTPPA_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating DNTP_c with {'enz': 'rt4736'}
# Updating DOCOSAt_c_e with {'gene_reaction_rule': ''}
# Updating DOCOSAt_c_l with {'gene_reaction_rule': ''}
# Updating DOCOSAt_c_rm with {'gene_reaction_rule': ''}
# Updating DOCOSCOAt_c_en with {'gene_reaction_rule': ''}
# Updating DOCOSCOAt_c_l with {'gene_reaction_rule': ''}
# Updating DOCOSCOAt_c_rm with {'gene_reaction_rule': ''}
# Updating DOLDPP_c with {'enz': 'rt5681'}
# Updating DOLDPt_c_l with {'gene_reaction_rule': ''}
# Updating DOLDPt_c_r with {'gene_reaction_rule': ''}
# Updating DOLGLCPt_c_r with {'gene_reaction_rule': ''}
# Updating DOLK_c with {'enz': 'rt0544'}
# Updating DOLPMMT_r with {'enz': 'rt3753'}
# Updating DOLPMT_c with {'enz': 'rt5116'}
# Updating DOLPt_c_r with {'gene_reaction_rule': ''}
# Updating DPCOAK_c with {'enz': 'rt2746'}
# Updating DPGM_c with {'enz': 'rt1542'}
# Updating DPGT_c with {'enz': 'rt3441'}
# Updating DPMVD_c with {'enz': 'rt3542'}
# Updating DPR_c with {'enz': 'rt8154'}
# Updating DRAPPRy_c with {'enz': 'rt8469'}
# Updating DRBK_c with {'enz': 'rt2501'}
# Updating DTMPK_c with {'enz': 'rt6884'}
# Updating DTTPt_c with {'gene_reaction_rule': ''}
# Updating DUDPt_c_n with {'gene_reaction_rule': ''}
# Updating DUMPt_c_n with {'gene_reaction_rule': ''}
# Updating DURIK1_c with {'gene_reaction_rule': ''}
# Updating DURIt_c_e with {'gene_reaction_rule': ''}
# Updating DUTPDP_c with {'enz': 'rt5532'}
# Updating DXHPSq9_c with {'enz': 'rt1830'}
# Updating E4HGLUt_c_m with {'gene_reaction_rule': ''}
# Updating E4HGLUt_c_x with {'gene_reaction_rule': ''}
# Updating E4Pt_c_m with {'gene_reaction_rule': ''}
# Updating EAR100y_c with {'enz': 'rt0302'}
# Updating EAR120y_c with {'enz': 'rt0302'}
# Updating EAR140y_c with {'enz': 'rt0302'}
# Updating EAR160y_c with {'enz': 'rt0302'}
# Updating EAR180y_c with {'enz': 'rt0302'}
# Updating EAR40y_c with {'enz': 'rt0302'}
# Updating EAR40y_m with {'enz': 'rt3469'}
# Updating EAR60y_c with {'enz': 'rt0302'}
# Updating EAR60y_m with {'enz': 'rt3469'}
# Updating EAR80y_c with {'enz': 'rt0302'}
# Updating EAR80y_m with {'enz': 'rt3469'}
# Updating ECOAH100_m with {'enz': 'rt6437'}
# Updating ECOAH100_x with {'enz': 'rt2994'}
# Updating ECOAH101e_x with {'enz': 'rt2994'}
# Updating ECOAH120_m with {'enz': 'rt6437'}
# Updating ECOAH120_x with {'enz': 'rt2994'}
# Updating ECOAH121a_m with {'enz': 'rt6437'}
# Updating ECOAH121a_x with {'enz': 'rt2994'}
# Updating ECOAH121d_x with {'enz': 'rt2994'}
# Updating ECOAH122e_x with {'enz': 'rt2994'}
# Updating ECOAH140_m with {'enz': 'rt6437'}
# Updating ECOAH140_x with {'enz': 'rt2994'}
# Updating ECOAH141b_m with {'enz': 'rt6437'}
# Updating ECOAH141b_x with {'enz': 'rt2994'}
# Updating ECOAH141c_m with {'enz': 'rt6437'}
# Updating ECOAH141c_x with {'enz': 'rt2994'}
# Updating ECOAH142_x with {'enz': 'rt2994'}
# Updating ECOAH143_x with {'enz': 'rt2994'}
# Updating ECOAH160_m with {'enz': 'rt6437'}
# Updating ECOAH160_x with {'enz': 'rt2994'}
# Updating ECOAH161b_m with {'enz': 'rt6437'}
# Updating ECOAH161b_x with {'enz': 'rt2994'}
# Updating ECOAH161c_m with {'enz': 'rt6437'}
# Updating ECOAH161c_x with {'enz': 'rt2994'}
# Updating ECOAH162_x with {'enz': 'rt2994'}
# Updating ECOAH163_x with {'enz': 'rt2994'}
# Updating ECOAH180_m with {'enz': 'rt6437'}
# Updating ECOAH180_x with {'enz': 'rt2994'}
# Updating ECOAH181a_m with {'enz': 'rt6437'}
# Updating ECOAH181a_x with {'enz': 'rt2994'}
# Updating ECOAH182_x with {'enz': 'rt2994'}
# Updating ECOAH183_x with {'enz': 'rt2994'}
# Updating ECOAH200_x with {'enz': 'rt2994'}
# Updating ECOAH220_x with {'enz': 'rt2994'}
# Updating ECOAH240_x with {'enz': 'rt2994'}
# Updating ECOAH260_x with {'enz': 'rt2994'}
# Updating ECOAH40_m with {'enz': 'rt6437'}
# Updating ECOAH40_x with {'enz': 'rt2994'}
# Updating ECOAH60_m with {'enz': 'rt6437'}
# Updating ECOAH60_x with {'enz': 'rt2994'}
# Updating ECOAH80_m with {'enz': 'rt6437'}
# Updating ECOAH80_x with {'enz': 'rt2994'}
# Updating ECOAI101a_x with {'enz': 'rt1925'}
# Updating ECOAI101d_x with {'enz': 'rt1925'}
# Updating ECOAI102e_x with {'enz': 'rt1925'}
# Updating ECOAI121a_x with {'enz': 'rt1925'}
# Updating ECOAI121b_x with {'enz': 'rt1925'}
# Updating ECOAI122c_x with {'enz': 'rt1925'}
# Updating ECOAI122d_x with {'enz': 'rt1925'}
# Updating ECOAI123e_x with {'enz': 'rt1925'}
# Updating ECOAI141a_x with {'enz': 'rt1925'}
# Updating ECOAI142c_x with {'enz': 'rt1925'}
# Updating ECOAI81e_x with {'enz': 'rt1925'}
# Updating ECOAI82e_x with {'enz': 'rt1925'}
# Updating ECOAR122_x with {'enz': 'rt4860'}
# Updating ECOAR142_x with {'enz': 'rt4860'}
# Updating ECOAR200_rm with {'enz': 'rt7873'}
# Updating ECOAR220_rm with {'enz': 'rt7873'}
# Updating ECOAR240_rm with {'enz': 'rt7873'}
# Updating ECOAR260_rm with {'enz': 'rt7873'}
# Updating ENO_c with {'enz': 'rt0669'}
# Updating EPGALURS_e with {'enz': 'rt2116'}
# Updating EPISTt_c_e with {'enz': 'rt6543'}
# Updating EPISTt_c_rm with {'gene_reaction_rule': ''}
# Updating EPISTt_l_rm with {'gene_reaction_rule': ''}
# Updating ERGSTESTt_c_rm with {'gene_reaction_rule': ''}
# Updating ERGSTESTt_l_rm with {'gene_reaction_rule': ''}
# Updating ERGSTGLCT_c with {'enz': 'rt5466'}
# Updating ERGSTt_c_e with {'enz': 'rt6543'}
# Updating ERGSTt_c_en with {'gene_reaction_rule': ''}
# Updating ERGSTt_c_l with {'gene_reaction_rule': ''}
# Updating ERGSTt_c_r with {'gene_reaction_rule': ''}
# Updating ERGSTt_c_rm with {'gene_reaction_rule': ''}
# Updating ERGTETROLt_c_e with {'gene_reaction_rule': ''}
# Updating ERGTETROLt_c_r with {'gene_reaction_rule': ''}
# Updating ETACt_c_e with {'gene_reaction_rule': ''}
# Updating ETFOXRq9_c with {'enz': 'rt1518rt1701rt1850'}
# Updating ETFOXRq9_m with {'enz': 'rt1518rt1701rt1850'}
# Updating ETHAK_c with {'enz': 'rt7614'}
# Updating ETHAt_c_e with {'gene_reaction_rule': ''}
# Updating ETNO2OX_c with {'enz': 'rt3897'}
# Updating ETOHt_c_e with {'gene_reaction_rule': ''}
# Updating ETOHt_c_m with {'gene_reaction_rule': ''}
# Updating EX_13BDglucan_e with {'gene_reaction_rule': ''}
# Updating EX_14dmlanost_e with {'gene_reaction_rule': ''}
# Updating EX_2mbac_e with {'gene_reaction_rule': ''}
# Updating EX_2mbald_e with {'gene_reaction_rule': ''}
# Updating EX_2mbtoh_e with {'gene_reaction_rule': ''}
# Updating EX_2phetoh_e with {'gene_reaction_rule': ''}
# Updating EX_3c3hmp_e with {'gene_reaction_rule': ''}
# Updating EX_3mbald_e with {'gene_reaction_rule': ''}
# Updating EX_3mop_e with {'gene_reaction_rule': ''}
# Updating EX_4abut_e with {'gene_reaction_rule': ''}
# Updating EX_4abz_e with {'gene_reaction_rule': ''}
# Updating EX_5aop_e with {'gene_reaction_rule': ''}
# Updating EX_5fthf_e with {'gene_reaction_rule': ''}
# Updating EX_8aonn_e with {'gene_reaction_rule': ''}
# Updating EX_Nfortyr2_e with {'gene_reaction_rule': ''}
# Updating EX_abt__D_e with {'gene_reaction_rule': ''}
# Updating EX_abt__L_e with {'gene_reaction_rule': ''}
# Updating EX_ac_e with {'gene_reaction_rule': ''}
# Updating EX_acald_e with {'gene_reaction_rule': ''}
# Updating EX_ade_e with {'gene_reaction_rule': ''}
# Updating EX_adn_e with {'gene_reaction_rule': ''}
# Updating EX_akg_e with {'gene_reaction_rule': ''}
# Updating EX_ala__L_e with {'gene_reaction_rule': ''}
# Updating EX_alltn_e with {'gene_reaction_rule': ''}
# Updating EX_alltt_e with {'gene_reaction_rule': ''}
# Updating EX_amet_e with {'gene_reaction_rule': ''}
# Updating EX_arab__D_e with {'gene_reaction_rule': ''}
# Updating EX_arab__L_e with {'gene_reaction_rule': ''}
# Updating EX_arach_e with {'gene_reaction_rule': ''}
# Updating EX_arg__L_e with {'gene_reaction_rule': ''}
# Updating EX_asn__L_e with {'gene_reaction_rule': ''}
# Updating EX_asp__L_e with {'gene_reaction_rule': ''}
# Updating EX_btd_e with {'gene_reaction_rule': ''}
# Updating EX_btn_c with {'gene_reaction_rule': ''}
# Updating EX_but_e with {'gene_reaction_rule': ''}
# Updating EX_ca2_e with {'gene_reaction_rule': ''}
# Updating EX_caro_c with {'gene_reaction_rule': ''}
# Updating EX_cellb_e with {'gene_reaction_rule': ''}
# Updating EX_chol_e with {'gene_reaction_rule': ''}
# Updating EX_cit_e with {'gene_reaction_rule': ''}
# Updating EX_cl_e with {'gene_reaction_rule': ''}
# Updating EX_co2_e with {'gene_reaction_rule': ''}
# Updating EX_cobalt2_e with {'gene_reaction_rule': ''}
# Updating EX_crn_e with {'gene_reaction_rule': ''}
# Updating EX_csn_e with {'gene_reaction_rule': ''}
# Updating EX_cu2_e with {'gene_reaction_rule': ''}
# Updating EX_cys__L_e with {'gene_reaction_rule': ''}
# Updating EX_cytd_e with {'gene_reaction_rule': ''}
# Updating EX_dad_2_e with {'gene_reaction_rule': ''}
# Updating EX_dann_e with {'gene_reaction_rule': ''}
# Updating EX_dca_e with {'gene_reaction_rule': ''}
# Updating EX_dcyt_e with {'gene_reaction_rule': ''}
# Updating EX_ddca_e with {'gene_reaction_rule': ''}
# Updating EX_dgsn_e with {'gene_reaction_rule': ''}
# Updating EX_din_e with {'gene_reaction_rule': ''}
# Updating EX_docosa_e with {'gene_reaction_rule': ''}
# Updating EX_dttp_e with {'gene_reaction_rule': ''}
# Updating EX_duri_e with {'gene_reaction_rule': ''}
# Updating EX_epist_e with {'gene_reaction_rule': ''}
# Updating EX_ergst_e with {'gene_reaction_rule': ''}
# Updating EX_ergtetrol_e with {'gene_reaction_rule': ''}
# Updating EX_etac_e with {'gene_reaction_rule': ''}
# Updating EX_etha_e with {'gene_reaction_rule': ''}
# Updating EX_etoh_e with {'gene_reaction_rule': ''}
# Updating EX_fald_e with {'gene_reaction_rule': ''}
# Updating EX_fe2_e with {'gene_reaction_rule': ''}
# Updating EX_fe3_e with {'gene_reaction_rule': ''}
# Updating EX_fecost_e with {'gene_reaction_rule': ''}
# Updating EX_fmn_e with {'gene_reaction_rule': ''}
# Updating EX_fol_e with {'gene_reaction_rule': ''}
# Updating EX_for_e with {'gene_reaction_rule': ''}
# Updating EX_fru_e with {'gene_reaction_rule': ''}
# Updating EX_fum_e with {'gene_reaction_rule': ''}
# Updating EX_g3pc_e with {'gene_reaction_rule': ''}
# Updating EX_g3pi_e with {'gene_reaction_rule': ''}
# Updating EX_gal_e with {'gene_reaction_rule': ''}
# Updating EX_galur_e with {'gene_reaction_rule': ''}
# Updating EX_gam6p_e with {'gene_reaction_rule': ''}
# Updating EX_gcald_e with {'gene_reaction_rule': ''}
# Updating EX_glc__D_e with {'gene_reaction_rule': ''}
# Updating EX_gln__L_e with {'gene_reaction_rule': ''}
# Updating EX_glu__L_e with {'gene_reaction_rule': ''}
# Updating EX_glx_e with {'gene_reaction_rule': ''}
# Updating EX_gly_e with {'gene_reaction_rule': ''}
# Updating EX_glyc_e with {'gene_reaction_rule': ''}
# Updating EX_gsn_e with {'gene_reaction_rule': ''}
# Updating EX_gthox_e with {'gene_reaction_rule': ''}
# Updating EX_gthrd_e with {'gene_reaction_rule': ''}
# Updating EX_gua_e with {'gene_reaction_rule': ''}
# Updating EX_h2o_e with {'gene_reaction_rule': ''}
# Updating EX_h_e with {'gene_reaction_rule': ''}
# Updating EX_hco3_e with {'gene_reaction_rule': ''}
# Updating EX_hdca_e with {'gene_reaction_rule': ''}
# Updating EX_hdcea_e with {'gene_reaction_rule': ''}
# Updating EX_his__L_e with {'gene_reaction_rule': ''}
# Updating EX_hom__L_e with {'gene_reaction_rule': ''}
# Updating EX_hxa_e with {'gene_reaction_rule': ''}
# Updating EX_hxan_e with {'gene_reaction_rule': ''}
# Updating EX_hxca_e with {'gene_reaction_rule': ''}
# Updating EX_hxdcal_e with {'gene_reaction_rule': ''}
# Updating EX_iamac_e with {'gene_reaction_rule': ''}
# Updating EX_iamoh_e with {'gene_reaction_rule': ''}
# Updating EX_ibtald_e with {'gene_reaction_rule': ''}
# Updating EX_ibutac_e with {'gene_reaction_rule': ''}
# Updating EX_ibutoh_e with {'gene_reaction_rule': ''}
# Updating EX_id3acald_e with {'gene_reaction_rule': ''}
# Updating EX_ile__L_e with {'gene_reaction_rule': ''}
# Updating EX_ind3eth_e with {'gene_reaction_rule': ''}
# Updating EX_inost_e with {'gene_reaction_rule': ''}
# Updating EX_ins_e with {'gene_reaction_rule': ''}
# Updating EX_k_e with {'gene_reaction_rule': ''}
# Updating EX_lac__D_e with {'gene_reaction_rule': ''}
# Updating EX_lac__L_e with {'gene_reaction_rule': ''}
# Updating EX_lanost_e with {'gene_reaction_rule': ''}
# Updating EX_leu__L_e with {'gene_reaction_rule': ''}
# Updating EX_lys__L_e with {'gene_reaction_rule': ''}
# Updating EX_mal__L_e with {'gene_reaction_rule': ''}
# Updating EX_malt_e with {'gene_reaction_rule': ''}
# Updating EX_man_e with {'gene_reaction_rule': ''}
# Updating EX_melib_e with {'gene_reaction_rule': ''}
# Updating EX_met__L_e with {'gene_reaction_rule': ''}
# Updating EX_mev__R_e with {'gene_reaction_rule': ''}
# Updating EX_mg2_e with {'gene_reaction_rule': ''}
# Updating EX_mmet_e with {'gene_reaction_rule': ''}
# Updating EX_mn2_e with {'gene_reaction_rule': ''}
# Updating EX_mobd_e with {'gene_reaction_rule': ''}
# Updating EX_na1_e with {'gene_reaction_rule': ''}
# Updating EX_nac_e with {'gene_reaction_rule': ''}
# Updating EX_nad_e with {'gene_reaction_rule': ''}
# Updating EX_nadp_e with {'gene_reaction_rule': ''}
# Updating EX_nh4_e with {'gene_reaction_rule': ''}
# Updating EX_ni2_e with {'gene_reaction_rule': ''}
# Updating EX_nmn_e with {'gene_reaction_rule': ''}
# Updating EX_o2_e with {'gene_reaction_rule': ''}
# Updating EX_oaa_e with {'gene_reaction_rule': ''}
# Updating EX_ocdca_e with {'gene_reaction_rule': ''}
# Updating EX_ocdcea_e with {'gene_reaction_rule': ''}
# Updating EX_octa_e with {'gene_reaction_rule': ''}
# Updating EX_orn_e with {'gene_reaction_rule': ''}
# Updating EX_pacald_e with {'gene_reaction_rule': ''}
# Updating EX_pap_e with {'gene_reaction_rule': ''}
# Updating EX_pectin_e with {'gene_reaction_rule': ''}
# Updating EX_phe__L_e with {'gene_reaction_rule': ''}
# Updating EX_pheac_e with {'gene_reaction_rule': ''}
# Updating EX_pi_e with {'gene_reaction_rule': ''}
# Updating EX_pnto__R_e with {'gene_reaction_rule': ''}
# Updating EX_ppa_e with {'gene_reaction_rule': ''}
# Updating EX_pro__L_e with {'gene_reaction_rule': ''}
# Updating EX_ptrc_e with {'gene_reaction_rule': ''}
# Updating EX_pydx5p_e with {'gene_reaction_rule': ''}
# Updating EX_pydxn_e with {'gene_reaction_rule': ''}
# Updating EX_pyr_e with {'gene_reaction_rule': ''}
# Updating EX_q9h2_e with {'gene_reaction_rule': ''}
# Updating EX_raffin_e with {'gene_reaction_rule': ''}
# Updating EX_rib__D_e with {'gene_reaction_rule': ''}
# Updating EX_ribflv_e with {'gene_reaction_rule': ''}
# Updating EX_sbt__D_e with {'gene_reaction_rule': ''}
# Updating EX_sbt__L_e with {'gene_reaction_rule': ''}
# Updating EX_ser__L_e with {'gene_reaction_rule': ''}
# Updating EX_so3_e with {'gene_reaction_rule': ''}
# Updating EX_so4_e with {'gene_reaction_rule': ''}
# Updating EX_spmd_e with {'gene_reaction_rule': ''}
# Updating EX_sprm_e with {'gene_reaction_rule': ''}
# Updating EX_srb__L_e with {'gene_reaction_rule': ''}
# Updating EX_succ_e with {'gene_reaction_rule': ''}
# Updating EX_sucr_e with {'gene_reaction_rule': ''}
# Updating EX_tag_c with {'gene_reaction_rule': ''}
# Updating EX_taur_e with {'gene_reaction_rule': ''}
# Updating EX_thm_e with {'gene_reaction_rule': ''}
# Updating EX_thmmp_e with {'gene_reaction_rule': ''}
# Updating EX_thmpp_e with {'gene_reaction_rule': ''}
# Updating EX_thr__L_e with {'gene_reaction_rule': ''}
# Updating EX_thymd_e with {'gene_reaction_rule': ''}
# Updating EX_tre_e with {'gene_reaction_rule': ''}
# Updating EX_trp__L_e with {'gene_reaction_rule': ''}
# Updating EX_ttcosa_e with {'gene_reaction_rule': ''}
# Updating EX_ttdca_e with {'gene_reaction_rule': ''}
# Updating EX_tyr__L_e with {'gene_reaction_rule': ''}
# Updating EX_ura_e with {'gene_reaction_rule': ''}
# Updating EX_urea_e with {'gene_reaction_rule': ''}
# Updating EX_uri_e with {'gene_reaction_rule': ''}
# Updating EX_val__L_e with {'gene_reaction_rule': ''}
# Updating EX_xan_e with {'gene_reaction_rule': ''}
# Updating EX_xtsn_e with {'gene_reaction_rule': ''}
# Updating EX_xyl__D_e with {'gene_reaction_rule': ''}
# Updating EX_xylt_e with {'gene_reaction_rule': ''}
# Updating EX_zn2_e with {'gene_reaction_rule': ''}
# Updating EX_zymst_e with {'gene_reaction_rule': ''}
# Updating F1PP_c with {'enz': 'rt0208'}
# Updating FACOA120tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA140tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA160tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA161tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA180tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA181tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA182tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA183tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA200tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA220tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA240tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOA260tabc_x with {'enz': 'rt1269rt4799'}
# Updating FACOAE100_x with {'enz': 'rt7680'}
# Updating FACOAE120_c with {'enz': 'rt4680'}
# Updating FACOAE120_x with {'enz': 'rt7680'}
# Updating FACOAE140_c with {'enz': 'rt4680'}
# Updating FACOAE140_x with {'enz': 'rt7680'}
# Updating FACOAE160_c with {'enz': 'rt0088'}
# Updating FACOAE160_x with {'enz': 'rt7680'}
# Updating FACOAE161_c with {'enz': 'rt0088'}
# Updating FACOAE161_x with {'enz': 'rt7680'}
# Updating FACOAE180_c with {'enz': 'rt0088'}
# Updating FACOAE180_x with {'enz': 'rt7680'}
# Updating FACOAE181_c with {'enz': 'rt0088'}
# Updating FACOAE181_x with {'enz': 'rt7680'}
# Updating FACOAE182_c with {'enz': 'rt0088'}
# Updating FACOAE182_x with {'enz': 'rt7680'}
# Updating FACOAE183_c with {'enz': 'rt0088'}
# Updating FACOAE183_x with {'enz': 'rt7680'}
# Updating FACOAE40_x with {'enz': 'rt7680'}
# Updating FACOAE60_x with {'enz': 'rt7680'}
# Updating FACOAE80_x with {'enz': 'rt7680'}
# Updating FACOAL100_x with {'enz': 'rt4187'}
# Updating FACOAL120_c with {'enz': 'rt7532'}
# Updating FACOAL120_l with {'enz': 'rt2799'}
# Updating FACOAL120_rm with {'enz': 'rt2799'}
# Updating FACOAL120_x with {'enz': 'rt7761'}
# Updating FACOAL140_l with {'enz': 'rt2799'}
# Updating FACOAL140_rm with {'enz': 'rt2799'}
# Updating FACOAL140_x with {'enz': 'rt7761'}
# Updating FACOAL160_l with {'enz': 'rt2799'}
# Updating FACOAL160_rm with {'enz': 'rt2799'}
# Updating FACOAL160_x with {'enz': 'rt7761'}
# Updating FACOAL161_l with {'enz': 'rt2799'}
# Updating FACOAL161_rm with {'enz': 'rt2799'}
# ...
# Updating PLAA2pc_rm with {'enz': 'rt5941'}
# Updating PLAA2pe_en with {'enz': 'rt4017'}
# Updating PLAA2pe_mm with {'enz': 'rt4445'}
# Updating PLACipc_m with {'enz': 'rt7489'}
# Updating PLACipc_r with {'enz': 'rt7489'}
# Updating PLACmip2c_m with {'enz': 'rt7489'}
# Updating PLACmip2c_r with {'enz': 'rt7489'}
# Updating PLACmipc_m with {'enz': 'rt7489'}
# Updating PLACmipc_r with {'enz': 'rt7489'}
# Updating PLACpail45p_c with {'enz': 'rt4487'}
# Updating PLACpail45p_n with {'enz': 'rt4487'}
# Updating PLACpail_c with {'enz': 'rt3387'}
# Updating PLACpg_mm with {'enz': 'rt3355'}
# Updating PLADpc_en with {'enz': 'rt5655'}
# Updating PMANM_c with {'enz': 'rt0873'}
# Updating PMDPHT_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating PMEMT_rm with {'enz': 'rt4380'}
# Updating PMEVK_c with {'enz': 'rt0334'}
# Updating PMI12346PS_c with {'enz': 'rt1395'}
# Updating PMI1346PS_c with {'enz': 'rt1395'}
# Updating PMPK_c with {'enz': 'rt4410'}
# Updating PMTCOAt_c_l with {'gene_reaction_rule': ''}
# Updating PMTCOAt_c_r with {'gene_reaction_rule': ''}
# Updating PMTCOAt_c_rm with {'gene_reaction_rule': ''}
# Updating PNP_c with {'enz': 'rt0004rt4016rt7908'}
# Updating PNTK_c with {'enz': 'rt5817'}
# Updating PNTOtps_e with {'enz': 'rt3985'}
# Updating POLYAO1_c with {'enz': 'rt7571'}
# Updating POLYAO2_c with {'enz': 'rt7571'}
# Updating POLYAO3_c with {'enz': 'rt7571'}
# Updating PPA_c with {'enz': 'rt7511'}
# Updating PPAt_c_e with {'gene_reaction_rule': ''}
# Updating PPAt_c_m with {'gene_reaction_rule': ''}
# Updating PPBNGD_c with {'enz': 'rt6350'}
# Updating PPBNGS_1_c with {'enz': 'rt5026'}
# Updating PPCDC_c with {'enz': 'rt0168'}
# Updating PPCK_c with {'enz': 'rt2473'}
# Updating PPGPPDP_c with {'enz': 'rt8139'}
# Updating PPIt_c_l with {'gene_reaction_rule': ''}
# Updating PPIt_c_m with {'gene_reaction_rule': ''}
# Updating PPIt_c_rm with {'gene_reaction_rule': ''}
# Updating PPIt_c_x with {'gene_reaction_rule': ''}
# Updating PPIt_m_mm with {'gene_reaction_rule': ''}
# Updating PPM_c with {'enz': 'rt5343'}
# Updating PPNCL2_c with {'enz': 'rt0510'}
# Updating PPND2_c with {'enz': 'rt7857'}
# Updating PPNDH_c with {'enz': 'rt5827'}
# Updating PPPG9t_c_m with {'gene_reaction_rule': ''}
# Updating PPPGO_m with {'enz': 'rt3499'}
# Updating PPTT_l with {'enz': 'rt4281'}
# Updating PPTT_m with {'enz': 'rt0532'}
# Updating PRAGSi_c with {'enz': 'rt5891'}
# Updating PRAIS_c with {'enz': 'rt5891'}
# Updating PRAIi_c with {'enz': 'rt8196'}
# Updating PRAMPC_c with {'enz': 'rt3278'}
# Updating PRASCSi_c with {'enz': 'rt0852'}
# Updating PRATPP_c with {'enz': 'rt3278'}
# Updating PREN9DPt_c_l with {'gene_reaction_rule': ''}
# Updating PREN9DPt_c_m with {'gene_reaction_rule': ''}
# Updating PRENT10_l with {'enz': 'rt4281'}
# Updating PRENT11_l with {'enz': 'rt4281'}
# Updating PRENT12_l with {'enz': 'rt4281'}
# Updating PRENT13_l with {'enz': 'rt4281'}
# Updating PRENT14_l with {'enz': 'rt4281'}
# Updating PRENT15_l with {'enz': 'rt4281'}
# Updating PRENT16_l with {'enz': 'rt4281'}
# Updating PRENT17_l with {'enz': 'rt4281'}
# Updating PRENT18_l with {'enz': 'rt4281'}
# Updating PRENT19_l with {'enz': 'rt4281'}
# Updating PRENT20_l with {'enz': 'rt4281'}
# Updating PRENT21_l with {'enz': 'rt4281'}
# Updating PRENT6_l with {'enz': 'rt4281'}
# Updating PRENT7_l with {'enz': 'rt4281'}
# Updating PRENT8_l with {'enz': 'rt4281'}
# Updating PRENT9_l with {'enz': 'rt4281'}
# Updating PRFGS_c with {'enz': 'rt6665'}
# Updating PRMICI_c with {'enz': 'rt3242'}
# Updating PROD2_m with {'enz': 'rt6234'}
# Updating PROTRS_c with {'enz': 'rt3118'}
# Updating PROt_c_m with {'gene_reaction_rule': ''}
# Updating PRPPS_c with {'enz': 'rt2777rt8224'}
# Updating PRPPt_c_m with {'gene_reaction_rule': ''}
# Updating PSD_gm with {'enz': 'rt0683'}
# Updating PSD_mm with {'enz': 'rt2136'}
# Updating PSD_vm with {'enz': 'rt0683'}
# Updating PSERT_c with {'enz': 'rt7036'}
# Updating PSPHPL_r with {'enz': 'rt3557'}
# Updating PSPHS_r with {'enz': 'rt6946'}
# Updating PSSA_rm with {'enz': 'rt3215'}
# Updating PSt_c_m with {'enz': 'rt4312'}
# Updating PSt_c_rm with {'gene_reaction_rule': ''}
# Updating PSt_en_rm with {'gene_reaction_rule': ''}
# Updating PSt_gm_rm with {'gene_reaction_rule': ''}
# Updating PSt_mm_rm with {'gene_reaction_rule': ''}
# Updating PSt_rm_vm with {'gene_reaction_rule': ''}
# Updating PTPAT_c with {'enz': 'rt6481'}
# Updating PTRCAT1_c with {'enz': 'rt7678'}
# Updating PTRCtpa_e with {'enz': 'rt1939'}
# Updating PTRCtpa_v with {'enz': 'rt1939'}
# Updating PUNP3_c with {'enz': 'rt7908'}
# Updating PUNP3_m with {'enz': 'rt7908'}
# Updating PUNP5_c with {'enz': 'rt7908'}
# Updating PYAM5PO_c with {'enz': 'rt2312'}
# Updating PYDAMK_c with {'enz': 'rt6177'}
# Updating PYDX5PS_c with {'enz': 'rt2768rt2769'}
# Updating PYDX5Pt_c_e with {'gene_reaction_rule': ''}
# Updating PYDXK_c with {'enz': 'rt6177'}
# Updating PYDXNK_c with {'enz': 'rt6177'}
# Updating PYDXNOR_c with {'enz': 'rt3182'}
# Updating PYDXNO_c with {'enz': 'rt2312'}
# Updating PYDXO_c with {'enz': 'rt2312'}
# Updating PYK_c with {'enz': 'rt4634'}
# Updating PYNP2r_c with {'gene_reaction_rule': ''}
# Updating PYRDC2_c with {'enz': 'rt7423'}
# Updating PYRDC_c with {'enz': 'rt7423'}
# Updating PYRtps_e with {'enz': 'rt1816'}
# Updating PYRtps_m with {'enz': 'rt7405rt8213'}
# Updating Q9H2t_c_e with {'gene_reaction_rule': ''}
# Updating Q9H2t_c_m with {'gene_reaction_rule': ''}
# Updating Q9MO_m with {'enz': 'rt7829'}
# Updating Q9MT1_m with {'enz': 'rt1845'}
# Updating Q9MT2_m with {'enz': 'rt3097'}
# Updating Q9OR_m with {'enz': 'rt1845rt3097rt7669rt7829rt8484'}
# Updating QUILSYN_c with {'gene_reaction_rule': ''}
# Updating QUINDH_c with {'enz': 'rt5341'}
# Updating QUINt_c_e with {'enz': 'rt5359'}
# Updating QULNt_c_m with {'gene_reaction_rule': ''}
# Updating RADHx_m with {'enz': 'rt5058'}
# Updating RAFH_e with {'enz': 'rt3242'}
# Updating RBFK_c with {'enz': 'rt0930'}
# Updating RBFK_m with {'enz': 'rt0930'}
# Updating RBFSa_c with {'enz': 'rt0910'}
# Updating RBFSb_c with {'enz': 'rt4127'}
# Updating RBK_D_c with {'enz': 'rt6000'}
# Updating RBK_c with {'enz': 'rt2501'}
# Updating RDH_c with {'enz': 'rt5407'}
# Updating RHMND2_c with {'enz': 'rt1893'}
# Updating RIBFLVt_c_m with {'gene_reaction_rule': ''}
# Updating RIBt_c_e with {'gene_reaction_rule': ''}
# Updating RLFC2O_c with {'enz': 'rt0434rt4960'}
# Updating RLFC2O_m with {'enz': 'rt0434rt4871'}
# Updating RNDR1_c with {'enz': 'rt2922rt5869rt6971'}
# Updating RNDR1_n with {'enz': 'rt2922rt5869rt6971'}
# Updating RNDR2_c with {'enz': 'rt2922rt5869rt6971'}
# Updating RNDR2_n with {'enz': 'rt2922rt5869rt6971'}
# Updating RNDR3_c with {'enz': 'rt2922rt5869rt6971'}
# Updating RNDR3_n with {'enz': 'rt2922rt5869rt6971'}
# Updating RNDR4_c with {'enz': 'rt2922rt5869rt6971'}
# Updating RNDR4_n with {'enz': 'rt2922rt5869rt6971'}
# Updating RNMK_c with {'enz': 'rt6206'}
# Updating RPE_c with {'enz': 'rt3505'}
# Updating RPI_c with {'enz': 'rt4920'}
# Updating SACCD1_c with {'enz': 'rt8465'}
# Updating SACCD2_c with {'enz': 'rt5719'}
# Updating SADT_c with {'enz': 'rt5075'}
# Updating SALCMOX_x with {'enz': 'rt7337'}
# Updating SAM24MT_c with {'enz': 'rt4692'}
# Updating SBPP1_r with {'enz': 'rt5044'}
# Updating SBPP2_r with {'enz': 'rt5044'}
# Updating SBP_c with {'enz': 'rt4269'}
# Updating SBTD_D2_c with {'enz': 'rt8084'}
# Updating SBTDt_c with {'gene_reaction_rule': ''}
# Updating SBTLt_c with {'gene_reaction_rule': ''}
# Updating SDPDS_c with {'enz': 'rt3986'}
# Updating SERAT_c with {'enz': 'rt6880'}
# Updating SERD_L_c with {'enz': 'rt0848'}
# Updating SERPT_r with {'enz': 'rt1057rt1935'}
# Updating SERTRS_c with {'enz': 'rt1878'}
# Updating SERt_c_m with {'enz': 'rt7910'}
# Updating SERt_c_r with {'gene_reaction_rule': ''}
# Updating SERt_c_rm with {'gene_reaction_rule': ''}
# Updating SERtps_e with {'enz': 'rt2976'}
# Updating SFGTHi_c with {'enz': 'rt1276'}
# Updating SHCHD2_c with {'enz': 'rt5201'}
# Updating SHCHF_c with {'enz': 'rt5201'}
# Updating SHK3Di_c with {'enz': 'rt5884'}
# Updating SHKK_c with {'enz': 'rt5884'}
# Updating SLCBK1_r with {'enz': 'rt2023'}
# Updating SO3R_c with {'enz': 'rt0376rt2006rt2682rt5201'}
# Updating SO3t_c_e with {'enz': 'rt4278'}
# Updating SO4t_c_e with {'enz': 'rt5751'}
# Updating SPHGLpK_r with {'enz': 'rt2023'}
# Updating SPHINGSt_c_e with {'enz': 'rt8393'}
# Updating SPHPL_r with {'enz': 'rt3557'}
# Updating SPMDAT_c with {'gene_reaction_rule': ''}
# Updating SPMDtpa_e with {'enz': 'rt7439'}
# Updating SPMS_c with {'enz': 'rt8465'}
# Updating SPRMAT_c with {'enz': 'rt1145'}
# Updating SPRMS_c with {'enz': 'rt4913'}
# Updating SPRMtpa_e with {'enz': 'rt6406'}
# Updating SPRMtpa_v with {'enz': 'rt2649'}
# Updating SQLEx_r with {'enz': 'rt5361'}
# Updating SQLEy_r with {'enz': 'rt5361'}
# Updating SQLS_c with {'enz': 'rt8223'}
# Updating SQLt_c_r with {'gene_reaction_rule': ''}
# Updating SRBt_c_e with {'gene_reaction_rule': ''}
# Updating SSALy_c with {'enz': 'rt0324'}
# Updating SSQ23EPXt_c_r with {'gene_reaction_rule': ''}
# Updating STATg_rm with {'enz': 'rt3431'}
# Updating STCOAt_c_l with {'gene_reaction_rule': ''}
# Updating STCOAt_c_rm with {'gene_reaction_rule': ''}
# Updating STEHz161_en with {'enz': 'rt5879'}
# Updating STEHz161_rm with {'enz': 'rt6249'}
# Updating STEHz181_en with {'enz': 'rt5879'}
# Updating STEHz181_rm with {'enz': 'rt6249'}
# Updating SUCCt2_m with {'enz': 'rt5142'}
# Updating SUCCt_c_e with {'gene_reaction_rule': ''}
# Updating SUCDq9_m with {'enz': 'rt3261rt3434rt3609rt7913'}
# Updating SUCFUMt_c_m with {'enz': 'rt4237'}
# Updating SUCOAS_m with {'enz': 'rt7599rt7776'}
# Updating SUCR_e with {'enz': 'rt6458'}
# Updating SULFOX2_c with {'enz': 'rt8390'}
# Updating TAGL_l with {'enz': 'rt1378'}
# Updating TAGL_m with {'enz': 'rt5949'}
# Updating TAGt_c_m with {'gene_reaction_rule': ''}
# Updating TAGt_c_rm with {'gene_reaction_rule': ''}
# Updating TAGt_l_rm with {'gene_reaction_rule': ''}
# Updating TALA_c with {'enz': 'rt1805'}
# Updating TAUDO_c with {'enz': 'rt0250'}
# Updating TAURt_c_e with {'gene_reaction_rule': ''}
# Updating TCHOLAtabc_v with {'enz': 'rt2898'}
# Updating TDCOAt_c_l with {'gene_reaction_rule': ''}
# Updating TDCOAt_c_rm with {'gene_reaction_rule': ''}
# Updating TDPDRR_c with {'enz': 'rt3425'}
# Updating THFGLUS_c with {'enz': 'rt6435'}
# Updating THIORDXi_m with {'enz': 'rt0553'}
# Updating THIORDXi_n with {'enz': 'rt6669rt6971'}
# Updating THIORDXi_x with {'enz': 'rt4894rt6971'}
# Updating THMP_c with {'enz': 'rt2517'}
# Updating THMtps_e with {'gene_reaction_rule': 'UNKNOWN'}
# Updating THRA2_c with {'enz': 'rt0854'}
# Updating THRA_c with {'enz': 'rt7814'}
# Updating THRD_L_m with {'enz': 'rt3541'}
# Updating THRS_c with {'enz': 'rt1374'}
# Updating THRTRS_c with {'enz': 'rt7480'}
# Updating THRt_c_m with {'gene_reaction_rule': ''}
# Updating THRtps_e with {'enz': 'rt5861'}
# Updating THYMDt_c_e with {'gene_reaction_rule': ''}
# Updating THZPSN1_c with {'gene_reaction_rule': ''}
# Updating THZPSN2_c with {'gene_reaction_rule': ''}
# Updating TKT1_c with {'enz': 'rt7263'}
# Updating TKT2_c with {'enz': 'rt7263'}
# Updating TMDK1_c with {'gene_reaction_rule': ''}
# Updating TMDPK_c with {'enz': 'rt8116'}
# Updating TMDPPK_c with {'enz': 'rt8116'}
# Updating TMDS_c with {'enz': 'rt2477'}
# Updating TMLYSOX_m with {'enz': 'rt0812'}
# Updating TMN_c with {'enz': 'rt4410'}
# Updating TMPK_c with {'gene_reaction_rule': ''}
# Updating TMPPP_c with {'enz': 'rt7845'}
# Updating TORULNOXi_c with {'gene_reaction_rule': 'UNKNOWN'}
# Updating TPI_c with {'enz': 'rt0932'}
# Updating TRDOXt_c_x with {'gene_reaction_rule': ''}
# Updating TRDRDt_c_x with {'gene_reaction_rule': ''}
# Updating TRDR_c with {'enz': 'rt1320'}
# Updating TRDR_m with {'enz': 'rt0553rt7114'}
# Updating TRE6PP_c with {'enz': 'rt3021rt3666'}
# Updating TRE6PS_c with {'enz': 'rt3021rt3666'}
# Updating TREH_v with {'enz': 'rt0212'}
# Updating TREt_c_v with {'gene_reaction_rule': ''}
# Updating TREtps_e with {'enz': 'rt0769'}
# Updating TROPNDH_c with {'enz': 'rt0537'}
# Updating TRPDC_c with {'enz': 'rt1736'}
# Updating TRPO2_c with {'enz': 'rt7555'}
# Updating TRPS1_c with {'enz': 'rt0894'}
# Updating TRPTRS_c with {'enz': 'rt6341'}
# Updating TRPTRS_m with {'enz': 'rt7165'}
# Updating TRPt_c_m with {'gene_reaction_rule': ''}
# Updating TTCCOAt_c_en with {'gene_reaction_rule': ''}
# Updating TTCCOAt_c_l with {'gene_reaction_rule': ''}
# Updating TTCCOAt_c_r with {'gene_reaction_rule': ''}
# Updating TTCCOAt_c_rm with {'gene_reaction_rule': ''}
# Updating TTCOSAt_c_e with {'gene_reaction_rule': ''}
# Updating TTCOSAt_c_l with {'gene_reaction_rule': ''}
# Updating TTCOSAt_c_rm with {'gene_reaction_rule': ''}
# Updating TTDCAt_c_e with {'enz': 'rt1544rt2799'}
# Updating TTDCAt_c_rm with {'gene_reaction_rule': ''}
# Updating TTDCAt_c_x with {'enz': 'rt5693'}
# Updating TTDCAt_l_rm with {'gene_reaction_rule': ''}
# Updating TYRCBOX_x with {'enz': 'rt5309'}
# Updating TYRTA_m with {'enz': 'rt5562'}
# Updating TYRTRS_c with {'enz': 'rt8273'}
# Updating TYRTRS_m with {'enz': 'rt4769'}
# Updating TYRt_c_m with {'gene_reaction_rule': ''}
# Updating TYRt_c_v with {'enz': 'rt6501'}
# Updating TYRt_c_x with {'gene_reaction_rule': ''}
# Updating TYRtps_v with {'enz': 'rt4375'}
# Updating UAGDP_c with {'enz': 'rt0711'}
# Updating UDPG4E_c with {'enz': 'rt0601'}
# Updating UDPGALt_c_g with {'enz': 'rt7574'}
# Updating UDPGLDC_c with {'enz': 'rt7050'}
# Updating UGLT_c with {'enz': 'rt2964'}
# Updating UMPK_c with {'enz': 'rt4822'}
# Updating UMPK_n with {'enz': 'rt4822'}
# Updating UMPt_c_n with {'gene_reaction_rule': ''}
# Updating UPP3MT_2_c with {'enz': 'rt2682'}
# Updating UPP3S_c with {'enz': 'rt2147'}
# Updating UPPDC1_c with {'enz': 'rt5811'}
# Updating UPPRT_c with {'enz': 'rt6727'}
# Updating URAtps_e with {'enz': 'rt4541'}
# Updating UREASE_c with {'enz': 'rt0958'}
# Updating UREA_c with {'enz': 'rt2839'}
# Updating URIDK2_n with {'enz': 'rt4822'}
# Updating URIDK2i_c with {'enz': 'rt4822'}
# Updating URIH_c with {'enz': 'rt4016'}
# Updating URIK1_c with {'enz': 'rt0265'}
# Updating URIK2_c with {'enz': 'rt0265'}
# Updating URItps_e with {'enz': 'rt1991'}
# Updating URO_c with {'enz': 'rt2202'}
# Updating UTPUMPtp_m with {'enz': 'rt4019'}
# Updating UTPt_c_m with {'enz': 'rt4019'}
# Updating VALTA_c with {'enz': 'rt6485'}
# Updating VALTA_m with {'enz': 'rt6242'}
# Updating VALTRS_c with {'enz': 'rt8160'}
# Updating VALTRS_m with {'enz': 'rt8160'}
# Updating VALt_c_m with {'gene_reaction_rule': ''}
# Updating VALtps_e with {'enz': 'rt5861'}
# Updating VANLLOX_x with {'enz': 'rt7726'}
# Updating XAND_c with {'enz': 'rt7594'}
# Updating XANt_c_e with {'gene_reaction_rule': ''}
# Updating XTSNt_c_e with {'gene_reaction_rule': ''}
# Updating XU5PFGT_x with {'enz': 'rt7263'}
# Updating XYLI1_c with {'enz': 'rt0738'}
# Updating XYLI2_c with {'enz': 'rt0738'}
# Updating XYLK_c with {'enz': 'rt8482'}
# Updating XYLRy_c with {'enz': 'rt1406'}
# Updating XYLTOR_c with {'enz': 'rt4609'}
# Updating XYLTt_c_e with {'enz': 'rt8486'}
# Updating XYLURx_c with {'enz': 'rt0736'}
# Updating XYLURy_c with {'enz': 'rt0736'}
# Updating XYLt_c_e with {'enz': 'RT12976'}
# Updating YUMPS_c with {'enz': 'rt7720'}
# Updating ZEAEPOX1_c with {'enz': 'rt0235'}
# Updating ZEAEPOX2_c with {'enz': 'rt3595'}
# Updating ZN2t_c_e with {'gene_reaction_rule': ''}
# Updating ZYM161t_en_rm with {'gene_reaction_rule': ''}
# Updating ZYM161t_l_rm with {'gene_reaction_rule': ''}
# Updating ZYM181t_en_rm with {'gene_reaction_rule': ''}
# Updating ZYM181t_l_rm with {'gene_reaction_rule': ''}
# Updating ZYMSTATer_RT_rm with {'enz': 'rt3431'}
# Updating ZYMSTt_c_en with {'gene_reaction_rule': ''}
# Updating ZYMSTt_c_rm with {'gene_reaction_rule': ''}
# Updating ZYMSTt_l_rm with {'gene_reaction_rule': ''}
# Updating compACYLCOA_c with {'gene_reaction_rule': ''}
# Updating compACYLCOA_l with {'gene_reaction_rule': ''}
# Updating compACYLCOA_m with {'gene_reaction_rule': ''}
# Updating compACYLCOA_r with {'gene_reaction_rule': ''}
# Updating compACYLCOA_rm with {'gene_reaction_rule': ''}
# Updating compACYLCOA_x with {'gene_reaction_rule': ''}
# Updating compCER_g with {'gene_reaction_rule': ''}
# Updating compCER_m with {'gene_reaction_rule': ''}
# Updating compCER_r with {'gene_reaction_rule': ''}
# Updating compFALPD_c with {'gene_reaction_rule': ''}
# Updating compFALPD_en with {'gene_reaction_rule': ''}
# Updating compFALPD_m with {'gene_reaction_rule': ''}
# Updating compFALPD_mm with {'gene_reaction_rule': ''}
# Updating compFALPD_rm with {'gene_reaction_rule': ''}
# Updating tpscu2_c_m with {'gene_reaction_rule': 'UNKNOWN'}
# Updating uniDOLDP_l with {'gene_reaction_rule': ''}

# %%
# convert df_enz_rxns to old ENZYME_stoich_curation file format from 2024 version of scRBA, for compatibility
df_rxn_enz_pairs = pd.DataFrame(columns=['id','rxn_src','enz','protein_stoich'])
catalyst_rxn_dict = {**spont_rxn_dict, **enz_rxn_dict}
for k, v in catalyst_rxn_dict.items():
	if k in spont_rxn_dict:
		catalyst_rxn_dict[k]['rxns'].extend(spont_rxn_dict[k]['rxns']) # adds rxns that were overrided by merger with enz_rxn_dict
		catalyst_rxn_dict[k]['rxns'] = list(dict.fromkeys(catalyst_rxn_dict[k]['rxns']))
for enz in catalyst_rxn_dict:
	enz_id = enz if enz != '' else 'SPONT'
	# don't seem to need MW of enzyme in prior RBA code
	prot_stoich_str = 'zeroCost' if enz in spont_GPRs + [''] else ','.join([prot+':'+str(catalyst_rxn_dict[enz]['protein_stoich'][prot]) for prot in catalyst_rxn_dict[enz]['protein_stoich']])
	for rxn in catalyst_rxn_dict[enz]['rxns']:
		dirs = []
		# add FWD and REV to rxn_src if those directions are possible
		if model.reactions.get_by_id(rxn).lower_bound < 0:
			dirs.append('REV')
		if model.reactions.get_by_id(rxn).upper_bound > 0:
			dirs.append('FWD')
		for dir in dirs:
			# print(enz,rxn)
			# df_rxn_enz_pairs = df_rxn_enz_pairs.append({'id':f'RXN-{rxn}_{dir}-{enz}','enz':enz,'gpr':'','protein_stoich':','.join([prot+':'+str(enz_rxn_dict[enz]['protein_stoich'][prot]) for prot in enz_rxn_dict[enz]['protein_stoich']]),'status':'automatically added'}, ignore_index=True)
			df_rxn_enz_pairs.loc[len(df_rxn_enz_pairs)] = [f'RXN-{rxn}_{dir}-{enz_id}',rxn,enz,prot_stoich_str]
			# df_rxn_enz_pairs = pd.concat([df_rxn_enz_pairs,pd.DataFrame({'id':f'RXN-{rxn}_{dir}-{enz}','enz':enz,'protein_stoich':','.join([prot+':'+str(enz_rxn_dict[enz]['protein_stoich'][prot]) for prot in enz_rxn_dict[enz]['protein_stoich']])})], ignore_index=True)

# sort by ID
df_rxn_enz_pairs = df_rxn_enz_pairs.sort_values(by='id')			
df_rxn_enz_pairs.to_csv('./model/ENZYME_rxn_pairs.tsv', sep='\t', index=False)

# %%
df_eqn = pd.DataFrame(columns=['id', 'type', 'coupling_type', 'coupling_species', 'reaction','tag','FBA_name','dir','enz_id'])
c = -1
medium = []

### Metabolic network reaction
# Exchange reactions
for rxn in model.reactions:
	# check if rxn is in df_enz
	# if rxn.id not in df_enz.rxn_src.to_list():
	if rxn.id[:3] == 'EX_':
		enz_id = 'SPONT'
		make_reversible = True
# else:
# 	gpr = rxn.gene_reaction_rule if rxn.gene_reaction_rule != "" else 'UNKNOWN'

		protein_stoich = 'zeroCost' if enz_id in spont_GPRs else ''
		
		met = [i for i in rxn.metabolites.keys()][0]
		c += 1
		tag = 'RXN'
		dir = 'FWD'
		new_id = f'{tag}-{rxn.id}_{dir}-{enz_id}'
		df_eqn.loc[c, 'id'] = new_id
		df_eqn.loc[c, 'type'] = 'metabolic'
		df_eqn.loc[c, 'reaction'] = 'MET-' + met.id + ' -->'
		# df_eqn.loc[c, ['FBA_name','dir']] = [rxn.id,'FWD']
		df_eqn.loc[c, ['tag','FBA_name','dir','enz_id']] = [tag,rxn.id,dir,enz_id]
		
		c += 1
		dir = 'REV'
		new_id = f'{tag}-{rxn.id}_{dir}-{enz_id}'
		df_eqn.loc[c, 'id'] = new_id
		df_eqn.loc[c, 'type'] = 'metabolic'
		df_eqn.loc[c, 'reaction'] = '-->' + 'MET-' + met.id
		# df_eqn.loc[c, ['FBA_name','dir']] = [rxn.id,'REV']
		df_eqn.loc[c, ['tag','FBA_name','dir','enz_id']] = [tag,rxn.id,dir,enz_id]

# Reactions that are not exchange reactions
for i in df_enz.index:
	rxn_id = df_enz.id[i]
	tag,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(rxn_id)
	
	if rxn_base_id[:3] == 'EX_':
		continue
	
	c += 1
	rxn_base = model.reactions.get_by_id(rxn_base_id)
	
	met_dict = metabolites_dict_from_reaction_equation_RBA(rxn_base.reaction)
	met_dict = {k:v for k,v in met_dict.items() if k != ''}
	met_dict = {'MET-' + k:v for k,v in met_dict.items()}
	if rxn_dir == 'REV':
		met_dict = {k:-v for k,v in met_dict.items()}
	elif rxn_dir == 'FWD':
		None
	else:
		print("Unknown ID that indicate reaction direction, only accepting 'FWD' and 'REV'")
	
	if enz_id not in spont_GPRs:
		df_eqn.loc[c, 'coupling_type'] = 'rxn_enz'
		df_eqn.loc[c, 'coupling_species'] = enz_id
	
	df_eqn.loc[c, 'id'] = rxn_id
	df_eqn.loc[c, 'type'] = 'metabolic'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(met_dict, arrow='-->')
	df_eqn.loc[c, ['tag','FBA_name','dir','enz_id']] = [tag,rxn_base_id,rxn_dir,enz_id]
	
### Enzyme synthesis network reaction
enz_stoich = OrderedDict()
for i in df_enz.index:
	enz_stoich[df_enz.enz[i]] = df_enz.protein_stoich[i]

c = df_eqn.shape[0] - 1
for enz_id,prot_str in enz_stoich.items():
	if prot_str == 'zeroCost':
		continue
	
	c += 1
	prot_str = prot_str.split(',')
	coeffs = OrderedDict({'PTMPRO-' + i.split(':')[0]:-int(i.split(':')[1]) for i in prot_str})
	coeffs['ENZ-' + enz_id] = 1
	
	df_eqn.loc[c, 'id'] = 'ENZSYN-' + enz_id
	df_eqn.loc[c, 'type'] = 'enzyme'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(coeffs, arrow='-->')

#these ENZLOAD equations also need to have their MW listed in the enz_mw_g_per_mmol file
#initialize an enzload sting
enzload_str = ""
for i in df_enz.index:
	if df_enz.protein_stoich[i] == 'zeroCost':
		continue
		
	c += 1
	coeffs = OrderedDict()
	coeffs['ENZ-' + df_enz.enz[i]] = -1

	enzload_id = 'ENZLOAD-' + df_enz.id[i][4:]

	#for debugging, comment out if unused
	#print("i: ",i,"\tenzload_id: ", enzload_id)
	
	df_eqn.loc[c, 'id'] = enzload_id
	df_eqn.loc[c, 'type'] = 'enzymeRxnLoad'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(coeffs, arrow='-->')

	#get the associated mw
	enz_mw = getattr(df_enz,"MW (g/mmol)")[i]

	new_line = enzload_id + "\t" + str(enz_mw) + "\n"
	enzload_str = enzload_str + new_line

# write the file resulting from enzload_str
with open('./model/enz_mw_g_per_mmol.txt', 'w') as f:
	f.write(enzload_str)
with open('../input/enz_mw_g_per_mmol.txt', 'w') as f:
	f.write(enzload_str)

### Ribosome
ribo_subunits = {}
c = df_eqn.shape[0] - 1
for rna in df_rnas.index:
	c += 1
	rna_stoich = OrderedDict({i:0 for i in ['MET-'+rna, 'MET-atp_c', 'MET-ctp_c',
											'MET-gtp_c', 'MET-utp_c', 'MET-ppi_c']})
	rna_stoich['RIBO-'+rna] = 1
	rna_stoich['MET-atp_c'] = -int(df_rnas.A[rna])
	rna_stoich['MET-ctp_c'] = -int(df_rnas.C[rna])
	rna_stoich['MET-gtp_c'] = -int(df_rnas.G[rna])
	rna_stoich['MET-utp_c'] = -int(df_rnas.U[rna])
	rna_stoich['MET-ppi_c'] = int(df_rnas.loc[rna, ['A','C','G','U']].sum())
	rna_stoich['BIO-rrna'] = df_rnas.loc[rna, 'MW (g/mmol)']
	
	df_eqn.loc[c, 'id'] = 'RIBOSYN-' + rna
	df_eqn.loc[c, 'type'] = 'ribosome'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(rna_stoich, arrow='-->')
	gene_expression_dict.setdefault(rna, []).append(df_eqn.loc[c, 'id'])
with open('./model/prosyn_ribo_subunits.txt', 'w') as f, open('./model/pro_ribo_subunits.txt', 'w') as f2, open('./model/kribo.txt', 'w') as f4, open('./model/j_ribo.txt', 'w') as f5, open('./model/ribosomes.txt', 'w') as f6:
	for file in [f,f2,f4,f5,f6]: file.write('/')
	for loc, ribo in ribo_dict.items():
		## proteins into ribosome subunits (to account for paralogs)
		ribo_stoich = OrderedDict()
		# if only 1 ribosome is present, all rRNAs are used
		rnas = [item for item in df_rnas.index if item.endswith(loc) or len(ribo_dict.keys()) == 1]
		# assume 1 of each rRNA and protein is used per ribosome
		for i in ribo.index:
			if ribo.id[i] in ribo_subunits:
				ribo_subunits[ribo.id[i]].append(loc[1:])
			else:
				ribo_subunits[ribo.id[i]] = [loc[1:]]
			if ribo.id[i] in rnas:
				ribo_stoich['RIBO-' + ribo.id[i]] = -1
			else:
				f.write("\n'"+loc[1:]+"'.'PROSYN-"+ribo.id[i]+"'")
				f2.write("\n'"+loc[1:]+"'.'"+ribo.id[i]+"'")
				# if it's not a paralog of another protein, all paralogs between it and the next non-paralog are treated as paralogs
				if pd.isnull(ribo.paralog[i]):
					ribosub_name = 'RIBOSUB-' + ribo.id[i]
				# add rxn converting the protein into the ribosome subunit (RIBOSUB prefix)
				c += 1
				ribosub_stoich = OrderedDict()
				ribosub_stoich['PTMPRO-' + ribo.id[i]] = -1
				ribosub_stoich[ribosub_name] = 1
				df_eqn.loc[c, 'id'] = 'RIBOSUBSYN-' + ribosub_name + '-FROM-' + ribo.id[i]
				df_eqn.loc[c, 'type'] = 'ribosome-subunit'
				df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(ribosub_stoich, arrow='-->')
				# add the ribosome subunit to the ribosome
				ribo_stoich[ribosub_name] = -1
		# making the ribosome itself from the subunits
		c += 1
		df_eqn.loc[c, 'id'] = 'RIBOSYN-ribonuc' if loc == '_c' else 'RIBOSYN-ribomito' if loc == '_m' else 'RIBOSYN-ribo'+loc[1:]
		# add to ribosome files
		ribo_id = "'"+loc[1:]+"'"
		f6.write('\n'+ribo_id); f5.write('\n'+ribo_id+".'"+df_eqn.loc[c, 'id']+"'"); f4.write('\n'+ribo_id+' '+str(kribo_default))
		df_eqn.loc[c, 'type'] = 'ribosome'
		df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(ribo_stoich, arrow='-->')
	for file in [f,f2,f4,f5,f6]: file.write('\n/')
# write the ribosome subunit stoichiometry to a json file
with open('./model/ribo_subunits.json', 'w') as f:
	json.dump(ribo_subunits, f)

# %% [markdown]
# #### Build files related to MW

# %%
data = getattr(df_pro,'MW (g/mmol)').to_dict()
ids = getattr(df_pro,'id').to_list()

#build the string to write
prot_mw_str = ""

#for each id
for id in ids:
	new_line = id + "\t" + str(data[id]) + "\n"
	prot_mw_str = prot_mw_str + new_line
# add dummy proteins to the string
for prot in dummy_list:
	new_line = prot["name"].replace('PROSYN-','') + "\t" + str(prot["MW"]) + "\n"
	prot_mw_str = prot_mw_str + new_line

#write to output
with open('./model/pro_mw_g_per_mmol.txt', 'w') as f:
	f.write(prot_mw_str)
with open('../input/pro_mw_g_per_mmol.txt', 'w') as f:
	f.write(prot_mw_str)

# %%
#TEST: this whole block. get MW list
mw_list = getattr(df_enz,"MW (g/mmol)").to_list()

#get enz list
enz_list = getattr(df_enz,"enz").to_list()

#create string for writing output file
enz_mw_str = "enz_id\tMW (g/mmol)\n"

#add to the string for enzyme entries
#need to initialize a counter
c = 0

#list to keep track of existing entries
#predefined values prevent adding unknown
existing_pro = ['nan','unknown']

for enz in enz_list:

	#only add a new line if unique entry
	if not(str(enz) in existing_pro):

		#for debugging, comment out if unused
		#print("enz: |",enz,"|, type: ",type(enz))
	
		new_line = str(enz) + "\t" + str(mw_list[c]) + "\n"

		#for debugging, comment out if unused
		#print(new_line)

		enz_mw_str = enz_mw_str + new_line

		existing_pro.append(enz)

	c = c + 1

#write to output
with open('../input/enz_mw_g_per_mmol_norxnmapped.txt', 'w') as f:
	f.write(enz_mw_str)

# %% [markdown]
# #### Protein file

# %%
### Protein

pro_lengths = dict()

c = df_eqn.shape[0] - 1
translation_loci = set()
unknown_ribo_prosyn = set()
protein_functions = dict()

def edit_stoich(stoich:OrderedDict,edits):
	if not pd.isna(edits):
		cofs_st = edits.split(',')
		cofs_st = OrderedDict({c.split(':')[0]:c.split(':')[1] for c in cofs_st})
		for k,v in cofs_st.items():
			stoich['MET-'+k] = -int(v)
	return stoich

for i in df_pro.index: 
	c += 1
	pro_id = df_pro.loc[i, 'id'] if 'id' in df_pro.columns else i
	prepro = 'PRO-' + str(pro_id) # preprotein (from translation)
	prot = 'PTMPRO-' + str(pro_id) # protein after post-translational modifications (PTMs)

	trans_st = OrderedDict()
	PTM_st = OrderedDict({prepro:-1,prot:1})
	for met in ['MET-atp_c', 'MET-h2o_c',
				'MET-adp_c', 'MET-pi_c', 'MET-h_c', 'MET-gtp_c',
				'MET-gdp_c']:
		trans_st[met] = 0
	seq = df_pro.sequence[i].replace("*","")

	trans_st = edit_stoich(trans_st,df_pro.trans_stoich_edits[i])
	PTM_st = edit_stoich(PTM_st,df_pro.PTM_stoich_edits[i])

	pro_lengths[i] = len(seq)
	for aa in df_aamap.index:
		trans_st[df_aamap.tRNA_in[aa]] = -seq.count(aa)
		trans_st[df_aamap.tRNA_out[aa]] = seq.count(aa)
				
	trans_st[prepro] = 1
	df_eqn.loc[c, 'coupling_type'] = 'prot_ribo'
	df_eqn.loc[c, 'coupling_species'] = 'ribo'
	
	# protein will occupy cellular space in its specific compartment
	if df_pro.subloc_assigned[i] in mito_compartments:
		trans_st['BIO-protmito'] = df_pro.loc[i, 'MW (g/mmol)']
	else:
		trans_st['BIO-protcyt'] = df_pro.loc[i, 'MW (g/mmol)']
	
	# Cost: Initiation: 1 ATP + 2 GTP (initiate and bind Methionine)
	for met in ['MET-atp_c', 'MET-h2o_c']:
		trans_st[met] -= 1
	for met in ['MET-adp_c', 'MET-pi_c', 'MET-h_c']:
		trans_st[met] += 1
				
	# Elongation: 2 GTP / cycle (2(n-1) cycles for n amino acids + 2 GTP from initiation = 2n GTP consumed so far)
	# (elongation process excludes Methionine since it is already bound in initiation process)
	# Termination and recycling: 1 GTP + 1 ATP: https://doi.org/10.1534/genetics.115.186221
	# 	However, we exclude these costs since it's not always required (e.g., via "leaky scanning"): https://doi.org/10.1093/nar/gkp765
	for met in ['MET-gtp_c', 'MET-h2o_c']:
		trans_st[met] -= 2*len(seq)
	for met in ['MET-gdp_c', 'MET-pi_c', 'MET-h_c']:
		trans_st[met] += 2*len(seq)
	
	df_eqn.loc[c, 'id'] = 'PROSYN-' + df_pro.id[i]

	# add translation rxn to gene_expression_dict list, or create a new list if it doesn't exist
	gene_expression_dict.setdefault(df_pro.gene_src[i], []).append(df_eqn.loc[c, 'id'])

	# add to protein functions dictionary under its gene_src
	protein_functions.setdefault(df_pro.gene_src[i], {})[df_pro.id[i]] = {}
	df_eqn.loc[c, 'type'] = 'protein'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(trans_st, arrow='-->')
	# Set ribosome translating the protein
	if df_pro.loc[i, 'translation_loc'] in ['unknown','any']:
		unknown_ribo_prosyn.add("'"+df_eqn.loc[c, 'id']+"'")
	else:
		translation_loci.add("'"+df_pro.loc[i, 'translation_loc']+"'.'"+df_eqn.loc[c, 'id']+"'")
	# add PTM reaction
	c += 1
	df_eqn.loc[c, 'id'] = 'PTM-' + df_pro.id[i]
	df_eqn.loc[c, 'type'] = 'proteinPTM'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(PTM_st, arrow='-->')
# write the protein length file
len_str = "/\n"
for prot in pro_lengths:
	len_str = len_str + "'PROSYN-" + prot + "' " + str(pro_lengths[prot]) + "\n"
for prot in dummy_list:
	len_str += "'" + prot["name"] + "' " + str(prot["medianL"]) + "\n"
len_str = len_str + "/"
with open('./model/RBA_proteinLength.txt', 'w') as f:
	f.write(len_str)

### Dummy protein
for prot in dummy_list:
	dummy_MW = prot["MW"]
	trans_st = make_dummy_protein_stoich(aa_standards_df=df_aamap, prot_df=prot["df"], length=prot["medianL"], rxn_name=prot["name"], mw=dummy_MW)

	c += 1
	# prot_st["BIO-protdummy"] = prot["MW"]
	df_eqn.loc[c, 'id'] = prot["name"]
	df_eqn.loc[c, 'coupling_type'] = 'prot_ribo'
	df_eqn.loc[c, 'coupling_species'] = 'ribo' #TEST: Update for ribonuc, ribomito, and other ribo types
	df_eqn.loc[c, 'type'] = 'protein'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(trans_st,
															arrow='-->', floatdecimal=6)
	if prot["translation_loc"] in ['unknown','any']:
		unknown_ribo_prosyn.add("'"+df_eqn.loc[c, 'id']+"'")
	else:
		translation_loci.add("'"+df_eqn.loc[c, 'id']+"'.'"+df_eqn.loc[c, 'id']+"'")

# Protein waste reactions
c = df_eqn.shape[0] - 1
with open('./model/pro_syn_waste.txt', 'w') as f:
	f.write('/')
	for i in df_pro.index: 
		for abbv,tag in {'':'PROSYN','PTM':'PTM'}.items():
			c += 1
			pro=abbv+'PRO-'+df_pro.id[i]
			new_st = OrderedDict()
			new_st[pro] = -1
			# add the protein's MW as the coefficient for BIO-protwasted
			new_st['BIO-protwasted'] = df_pro.loc[i, 'MW (g/mmol)']
			
			pw_id = f"{abbv}PROWASTE-{df_pro.id[i]}"
			f.write(f"\n'{tag}-{df_pro.id[i]}'.'{pw_id}'")

			df_eqn.loc[c, 'id'] = pw_id
			df_eqn.loc[c, 'type'] = 'proteinWaste'
			df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(new_st, arrow='-->')

	f.write('\n/')
# Pseudoreaction representing mass of waste protein (for kapps): PROWASTE-TOTALPROTEIN
c += 1
df_eqn.loc[c, 'id'] = 'PROWASTE-TOTALPROTEIN'
df_eqn.loc[c, 'type'] = 'proteinWaste'
df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA({'BIO-protwasted':-1}, arrow='-->')
for loc in ['modeled','dummy','cyt','mito']: # add PROWASTE rxns for biomass-related byproduct of PROSYN rxns, to support simulations at 0 growth
	c += 1
	df_eqn.loc[c, 'id'] = 'PROWASTE-PROT'+loc.upper()
	df_eqn.loc[c, 'type'] = 'proteinWaste'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA({'BIO-prot'+loc:-1}, arrow='-->')

### Write translation localization lists
with open('./model/translation.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(list(translation_loci)) + ['/']))
with open('./model/translated_by_any_ribo.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(list(unknown_ribo_prosyn)) + ['/']))

### Biomass
for i in df_biom.index:
	c += 1
	if not pd.isna(df_biom.rxn_id[i]):
		df_eqn.loc[c, 'id'] = df_biom.rxn_id[i]
		df_eqn.loc[c, 'type'] = 'biomass'
		df_eqn.loc[c, 'reaction'] = df_biom.rxn_equation[i]
# make into file RBA_rxns_whole_biomass.txt
with open('./model/RBA_rxns_whole_biomass.txt', 'w') as f:
	# find whole_biomass_rxns in df_eqn and write them to file
	f.write('\n'.join(['/'] + [i for i in whole_biomass_rxns if i in df_eqn.id.to_list()] + ['/']))

# %%
for k,v in gene_expression_dict.items():
	# check for entries in v starting with "'RIBO"
	if any([i.startswith("'RIBO") for i in v]):
		print(f"Warning: {k} has entries starting with 'RIBO' in gene_expression_dict")

# %%
# save gene list to file
with open('./model/genes.txt', 'w') as f:
	f.write('\n'.join(['/'] + [f"'{i}'" for i in genes] + ['/']))
for gene in genes:
	if gene not in gene_expression_dict:
		gene_expression_dict[gene] = []
# remove duplicates from gene_expression_dict, preserve order
gene_expression_dict = {k: list(dict.fromkeys([f"'{i}'" for i in v])) for k, v in gene_expression_dict.items()}
# save gene-protein mapping to file
with open('./model/genes_expression.txt', 'w') as f:
	f.write('\n'.join(['/'] + [f"'{gene}'.({','.join(gene_expression_dict[gene])})" for gene in genes if gene_expression_dict[gene]] + ['/']))

# %%
# make extra kapp calculation files
directory = '../GAMS/parameterization/enz_from_proteome'
if not os.path.exists(directory):
	os.makedirs(directory)

with open(directory + '/pro_and_enz.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(list(set(["'ENZ-" + i + "'" for i in enz_list] + ["'PTMPRO-" + i + "'" for i in df_pro.index]))) + ['/']))

# %% [markdown]
# #### Save excel files

# %%
df_eqn.to_csv('./model/RBA_stoichiometry.tsv', sep='\t', index=None)

# %% [markdown]
# # Build GAMS Sij and flux bounds (originally A02_build_GAMS_Sij_and_fluxBounds.ipynb)

# %% [markdown]
# #### Load excel file

# %%
df_eqn = read_spreadsheet('./model/RBA_stoichiometry.tsv')

# %% [markdown]
# #### Assemble list of species

# %%
met_list_raw = []
for i in df_eqn.index:
	met_dict = metabolites_dict_from_reaction_equation_RBA(df_eqn.reaction[i])
	met_list_raw += met_dict.keys()

met_list = sorted(list(set(met_list_raw)))
met_list = [i for i in met_list if i != '']
with open('./model/RBA_species.txt', 'w') as f:
	f.write('\n'.join(['/'] + ["'" + i + "'" for i in met_list] + ['/']))
# add list of demand rxns for each metabolite (for testing purposes)
demand_list = ["DM-" + i for i in met_list]
# WIP: add to df_eqn
with open('./model/RBA_rxns_demand.txt', 'w') as f:
	f.write('\n'.join(['/'] + ["'DM-" + i + "'" for i in met_list] + ['/']))

# %% [markdown]
# #### Assemble list of reactions

# %%
rxn_list = df_eqn.id.to_list()
rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of uptake reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(i)
	if tag == 'RXN' and rxn_base_id[:3] == 'EX_' and rxn_dir == 'REV':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_EXREV.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of secretion reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(i)
	if tag == 'RXN' and rxn_base_id[:3] == 'EX_' and rxn_dir == 'FWD':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_EXFWD.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of protein waste reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag = i.split('-')[0]
	if tag in ['PROWASTE','PTMPROWASTE']:
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_prowaste.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of enzyme syn reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag = i.split('-')[0]
	if tag == 'ENZSYN':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_enzsyn.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of enzyme load reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag = i.split('-')[0]
	if tag == 'ENZLOAD':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
# list created so GAMS knows which ENZLOAD corresponds to which rxn
rxn_enzload_coupling_list = [i + '.' + i.replace('ENZLOAD-','RXN-') + ' 1' for i in rxn_list]
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_enzload.txt', 'w') as f:
	f.write('\n'.join(rxn_list))
with open('./model/RBA_rxn_enzload_coupling.txt', 'w') as f:
	f.write('\n'.join(['/'] + rxn_enzload_coupling_list + ['/']))

# %% [markdown]
# #### Get list of metabolic network reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag = i.split('-')[0]
	if tag == 'RXN':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_rxnmetabolicnetwork.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %%
# Make k_app (enzyme turnover rate) file draft using placeholder values
kapp_list = []
kapp_list = [i + " 360000" for i in rxn_list if i != '/']
kapp_list = ['/'] + kapp_list + ['/']
with open('./model/kapp_placeholders.txt', 'w') as f:
	f.write('\n'.join(kapp_list))

# %% [markdown]
# #### Assemble stoichiometry

# %%
# make extra kapp calculation files
directory = '../GAMS/parameterization/enz_from_proteome/'
if not os.path.exists(directory):
	os.makedirs(directory)

sij = []
rxns_enz = []
rxns_proenz = []
sij_proenz = []

for i in df_eqn.index:
	x = metabolites_dict_from_reaction_equation_RBA(df_eqn.reaction[i])
	met_dict = dict()
	for k,v in x.items():
		if k == '':
			continue
		# note when a protein is used in a reaction other than its PROWASTE and production reactions
		met = k.split('-',1)[1]
		if k.startswith('PTMPRO-') and df_eqn.id[i] not in ['PTMPROWASTE-' + met,'PTM-' + met]:
			for gene,prots in protein_functions.items():
				if met in prots:
					protein_functions[gene][met].update({df_eqn.id[i]:v})
					break
		if v.is_integer():
			met_dict[k] = int(v)
		else:
			met_dict[k] = v
			
	rxn_prefixes = ('ENZ', 'PTM-')
	if df_eqn.id[i].startswith(rxn_prefixes):
		if df_eqn.id[i].startswith("PTM-"):
			rxns_proenz.append("'" + df_eqn.id[i].replace('PTM-','PROIN-') + "'")
		else:
			rxns_proenz.append("'" + df_eqn.id[i] + "'")
			rxns_enz.append("'" + df_eqn.id[i] + "'")
		# sij.append("'" + df_eqn.id[i] + "'.'" + df_eqn.id[i] + "' 1")
		for k,v in met_dict.items():
			sij.append("'" + k + "'.'" + df_eqn.id[i] + "' " + str(v))
			if k.startswith('PTMPRO-') or k.startswith('ENZ-'):
				sij_proenz.append("'" + k + "'.'" + df_eqn.id[i].replace('PTM-','PROIN-') + "' " + str(v))
	else:
		for k,v in met_dict.items():
			sij.append("'" + k + "'.'" + df_eqn.id[i] + "' " + str(v))
	
sij = ['/'] + sij + ['/']
with open('./model/RBA_sij.txt', 'w') as f:
	f.write('\n'.join(sij))
# write protein functions to file
with open('./protein_functions.json', 'w') as f:
	json.dump(protein_functions, f)
# make set of all proteins in protein_functions with no modeled functions
proteins_without_modeled_functions = set()
# identify them by checking if all values within values are empty
for gene,prots in protein_functions.items():
	for prot,funcs in prots.items():
		# if all values are empty, add to set
		if not any(funcs.values()):
			proteins_without_modeled_functions.add(prot)
with open('./proteins_without_modeled_functions.txt', 'w') as f:
	f.write('\n'.join(sorted(list(proteins_without_modeled_functions))))
with open(directory + 'rxns_enz.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(rxns_enz) + ['/']))
with open(directory + 'rxns_pro_and_enz.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(rxns_proenz) + ['/']))
with open(directory + 'sij_pro_and_enz.txt', 'w') as f:
	f.write('\n'.join(['/'] + sij_proenz + ['/']))

# %% [markdown]
# # Build GAMS RBA constraints (originally A03_build_GAMS_RBA_constraints.ipynb)

# %%
#### LOAD INPUTS AND PARAMETERS
copy_to_gams = True # if True, copy the model to the gams folder

# Stoichiometry
df_stoich = read_spreadsheet('./model/RBA_stoichiometry.tsv')
df_stoich.index = df_stoich.id.to_list()

# %%
### Write prosyn reaction
idx = [i for i in df_stoich.index if i[:7] == 'PROSYN-']
prosyn = ["'" + i + "'" for i in idx]
prosyn = ['/'] + prosyn + ['/']
with open('./model/RBA_rxns_prosyn.txt', 'w') as f:
	f.write('\n'.join(prosyn))
## write ribosyn set
idx = [i for i in df_stoich.index if i[:8] == 'RIBOSYN-']
ribosyn = ["'" + i + "'" for i in idx]
ribosyn = ['/'] + ribosyn + ['/']
with open('./model/RBA_rxns_ribosyn.txt', 'w') as f:
	f.write('\n'.join(ribosyn))

# %%
# Make fwd and reversible rxn list for metabolic network and all rxns (not needed but helpful for testing)
# Also, make flux coupling analysis file in case you use that for testing

# Using Patrick's FCA code
rxn_types = {'irrev': 0, 'reversible-fwd-half': 1, 'reversible-rev-half': 2, 'pseudoreaction': 3, 'exchange-fwd-half': 4, 'exchange-rev-half': 5}

rev_rxn_list = []; rev_list = []
fwd_rxn_list = []; fwd_list = []
fca_list = []

for i in df_stoich.id:
	tag,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(i)
	#print("'"+i+"' "+str(rxn_types['irrev']))
	#print(rxn_base_id)
	#print(i,'\t',tag,'\t',rxn_dir)
	if rxn_dir == 'FWD':
		fwd_list.append(i)
		if tag == 'RXN':
			fwd_rxn_list.append(i)
		if rxn_base_id[:3] == 'EX_':
			fca_list.append("'"+i+"' "+str(rxn_types['exchange-fwd-half']))
		# Add as irreversible if no counterpart found in other direction
		elif i.replace("_FWD-","_REV-") not in df_stoich.id:
			fca_list.append("'"+i+"' "+str(rxn_types['irrev'])) 
		else:
			fca_list.append("'"+i+"' "+str(rxn_types['reversible-fwd-half']))
	elif rxn_dir == 'REV':
		rev_list.append(i)
		if tag == 'RXN':
			rev_rxn_list.append(i)
		if rxn_base_id[:3] == 'EX_':
			fca_list.append("'"+i+"' "+str(rxn_types['exchange-rev-half']))
		# Add as irreversible if no counterpart found in other direction
		elif i.replace("_REV-","_FWD-") not in df_stoich.id:
			fca_list.append("'"+i+"' "+str(rxn_types['irrev'])) 
		else:
			fca_list.append("'"+i+"' "+str(rxn_types['reversible-rev-half']))
	else:
		fca_list.append("'"+i+"' "+str(rxn_types['irrev'])) 

fwd_rxn_list = ["'" + i + "'" for i in fwd_rxn_list if i != '/']
fwd_rxn_list = ['/'] + fwd_rxn_list + ['/']
with open('./model/RBA_rxns_rxnmetabolicnetworkFWD.txt', 'w') as f:
	f.write('\n'.join(fwd_rxn_list))
rev_rxn_list = ["'" + i + "'" for i in rev_rxn_list if i != '/']
rev_rxn_list = ['/'] + rev_rxn_list + ['/']
with open('./model/RBA_rxns_rxnmetabolicnetworkREV.txt', 'w') as f:
	f.write('\n'.join(rev_rxn_list))

fwd_list = ["'" + i + "'" for i in fwd_list if i != '/']
fwd_list = ['/'] + fwd_list + ['/']
with open('./model/RBA_rxns_FWD.txt', 'w') as f:
	f.write('\n'.join(fwd_list))
rev_list = ["'" + i + "'" for i in rev_list if i != '/']
rev_list = ['/'] + rev_list + ['/']
with open('./model/RBA_rxns_REV.txt', 'w') as f:
	f.write('\n'.join(rev_list))

fca_list = ['/'] + fca_list + ['/']
with open('./model/rxntype.txt', 'w') as f:
	f.write('\n'.join(fca_list))

# %%
# creating set pairing SM values w/ RBA ones, for use in converting flux constraints from SM format to RBA

# filter out rxns with no FBA_name
df_sm = df_stoich[df_stoich.FBA_name.notnull()]
# get SM rxn IDs from FBA_name column
sm_rxn_ids = df_sm.FBA_name.to_list()
# get RBA rxn IDs from index
rba_rxn_ids = df_sm.index.to_list()
rba_rxn_dirs = [extract_details_from_rxnid(i)[2] for i in rba_rxn_ids]
# convert dir to -1 if rev, 1 otherwise
rba_rxn_dirs = [-1 if i == 'REV' else 1 for i in rba_rxn_dirs]
# create list of strings pairing SM rxn IDs with RBA rxn IDs
sm_rba_rxn_pairs_dict = {rba_rxn_ids[i]:sm_rxn_ids[i] for i in range(0, len(sm_rxn_ids))}
# save as JSON file
with open('./model/SM_RBA_rxn_pairs.json', 'w') as f:
	json.dump(sm_rba_rxn_pairs_dict, f)
sm_rba_rxn_pairs = ["'"+sm_rxn_ids[i]+"'.'"+rba_rxn_ids[i]+"'"+' '+str(int(rba_rxn_dirs[i])) for i in range(0, len(sm_rxn_ids))]
# convert SM rxn bounds to RBA format; for each sm rxn, get the corresponding rba rxn and its direction
with open('./model/SM_rxn_bounds.txt', 'w') as f:
	delim = ' '
	sm_rxns_checked = []
	# find longest rxn ID for formatting purposes
	max_sm_rxn_id_len = max([len(i)+2 for i in sm_rxn_ids])+1
	max_lb_len = max([len(str(rxn.lower_bound)) for rxn in model.reactions if rxn.id in sm_rxn_ids])+1
	max_ub_len = max([len(str(rxn.upper_bound)) for rxn in model.reactions if rxn.id in sm_rxn_ids])
	# write headers to file, with ljust
	f.write(f"{'':>{max_sm_rxn_id_len}}{'lo':>{max_lb_len}}{' up':<{max_ub_len}}")
	for rba_rxn,sm_rxn in sm_rba_rxn_pairs_dict.items():
		# find bounds of sm rxn in model
		rxn = model.reactions.get_by_id(sm_rxn)
		ub = rxn.upper_bound
		lb = rxn.lower_bound

		if sm_rxn not in sm_rxns_checked:
			sm_rxns_checked.append(sm_rxn)
			name=f"'{sm_rxn}'"
			# make string with SM rxn ID, lb, and ub, using max lengths for formatting
			f.write(f"\n{name:>{max_sm_rxn_id_len}}{str(lb):>{max_lb_len}} {str(ub):<{max_ub_len}}")
# write to file
with open('./model/SM_RBA_rxn_pairs.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(sm_rba_rxn_pairs) + ['/']))
# make file w/ all FBA IDs
with open('./model/SM_rxn_ids.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(["'"+i+"'" for i in set(sm_rxn_ids)]) + ['/']))

# %%
# make file for all formula weights (some may be inaccurate due to R groups and other non-standard groups)
with open('./model/formula_weights.txt','w') as f:
	f.write('/\n')
	for met in model.metabolites:
		# write met name, formula, and formula weight
		try:
			formula = str(met.formula)
			mw = str(met.formula_weight)
		except:
			mw = 'unknown'
			formula = 'unknown'
		f.write(str(met.id) + '\t' + formula + '\t' + mw + '\n')
	f.write('/')
# Out:
# /Applications/anaconda3/envs/rba/lib/python3.9/site-packages/cobra/core/metabolite.py:191: UserWarning: The element 'R' does not appear in the periodic table
#   warn(f"The element {e} does not appear in the periodic table")
# /Applications/anaconda3/envs/rba/lib/python3.9/site-packages/cobra/core/metabolite.py:191: UserWarning: The element 'Tr' does not appear in the periodic table
#   warn(f"The element {e} does not appear in the periodic table")
# /Applications/anaconda3/envs/rba/lib/python3.9/site-packages/cobra/core/metabolite.py:191: UserWarning: The element 'Fd' does not appear in the periodic table
#   warn(f"The element {e} does not appear in the periodic table")
# /Applications/anaconda3/envs/rba/lib/python3.9/site-packages/cobra/core/metabolite.py:191: UserWarning: The element 'M' does not appear in the periodic table
#   warn(f"The element {e} does not appear in the periodic table")

# %%
# for AA in df_aamap, find all mets in met_list that match its name (without the location)
with open('./model/aa.txt', 'w') as f, open('./model/tRNAs.txt', 'w') as f2:
	fis = [f,f2]
	for fi in fis: fi.write('/')
	for aa in df_aamap.index:
		aa_mets = [f"'{met}'" for met in met_list if met.rsplit('_',1)[0] == df_aamap.tRNA_in[aa].rsplit('_',1)[0]]
		f.write(f"\n'{aa}'")
		if aa_mets:
			f2.write(f"\n'{aa}'.({','.join(aa_mets)})")
	for fi in fis: fi.write('\n/')

# %%
# write combinations of gene_src and protein IDs in form 'gene_src'.('protein1','protein2',...)
with open('./model/proteins_and_locations.txt', 'w') as f, open('./model/proteins.txt', 'w') as f2:
	fis = [f,f2]
	for fi in fis: fi.write('/')
	for gene,prots in protein_functions.items():
		prots_str = ','.join([f"'PROSYN-{prot}'" for prot in prots])
		f.write(f"\n'{gene}'.({prots_str})")
		f2.write(f"\n'{gene}'")
	for fi in fis: fi.write('\n/')

# %%
if copy_to_gams: # automatically copies the model folder to the GAMS folder (removing the previous version), if you choose to
	import shutil
	# copy "model" folder to GAMS folder
	# Source folder path
	source_folder = './model'

	# Destination folder path
	destination_folder = '../GAMS/model'

	# Remove the existing destination folder
	shutil.rmtree(destination_folder)

	# Copy the folder
	shutil.copytree(source_folder, destination_folder)

# %%
# check if any enzymes likely have cofactors counted multiple times
for enz in set(df_enz['enz']):
	# find 1st row where the enz matches
	prot_stoich_str = df_enz[df_enz['enz'] == enz].iloc[0]['protein_stoich']
	if pd.isna(prot_stoich_str):
		continue
	# parse the protein_stoich string into a dictionary
	# print(enz, prot_stoich_str)
	prot_stoich = {item.split(':')[0]: float(item.split(':')[1]) for item in prot_stoich_str.split(',') if ':' in item and not pd.isna(item)}
	if not prot_stoich:
		continue
	rxns = set(df_enz[df_enz['enz'] == enz]['rxn_src'].to_list())
	# remove blocked reactions
	rxns = [rxn for rxn in rxns if model.reactions.get_by_id(rxn).bounds != (0, 0)]
	# find the trans_stoich_edits and ptm_stoich_edits for all proteins comprising it
	possible_cofactors = dict()
	for pro in prot_stoich.keys():
		if pro in df_pro.index:
			met_dict = dict()
			# Collect edits, filter out NaN, and convert to string
			edits = [df_pro.loc[pro,'trans_stoich_edits'], df_pro.loc[pro,'PTM_stoich_edits']]
			edits = [str(e) for e in edits if pd.notna(e)]
			if not edits:
				continue
			met_items = set(','.join(edits).split(','))
			met_dict = {i.split(':')[0]: float(i.split(':')[1]) for i in met_items if not pd.isna(i) and ':' in i}
			for k,v in met_dict.items():
				if v > 0: # i.e., if it's consumed
					if k in possible_cofactors:
						print(f"Warning: Enzyme {enz} has cofactor {k} counted multiple times, including subunits {possible_cofactors[k]} and {pro}.")
					possible_cofactors.setdefault(k, []).append(pro)
	if possible_cofactors:
		# print(enz,possible_cofactors)
		# find the reactions that have the same cofactors
		cofactors_in_rxns = set()
		for rxn in rxns:
			rxn_cofactors = set()
			# get the stoichiometry of the reaction
			rxn_stoich_dict = model.reactions.get_by_id(rxn).metabolites
			if rxn_stoich_dict is None:
				continue
			for met, coef in rxn_stoich_dict.items():
				# if coef < 0 and met.id in [i for i in possible_cofactors.keys()]:
				if coef < 0 and met.id.rsplit('_',1)[0] in [i.rsplit('_',1)[0] for i in possible_cofactors.keys()]:
					rxn_cofactors.add(met.id)
					cofactors_in_rxns.add(met.id)
		if cofactors_in_rxns:
			print(f"Enzyme {enz} has cofactors {cofactors_in_rxns} in its reactions.")
			# print the reactions that have the same cofactors
			for rxn in rxns:
				for cofactor in cofactors_in_rxns:
					if cofactor in [met.id for met in model.reactions.get_by_id(rxn).metabolites.keys()]:
						print(f"  - {rxn} has cofactor {cofactor}")
# Out:
# Warning: Enzyme PDHCPLX has cofactor thmpp_c counted multiple times, including subunits ['rt5580'] and rt5262.
# Warning: Enzyme MET1213 has cofactor fad_c counted multiple times, including subunits ['rt0876'] and rt7115.
# Enzyme rt2671 has cofactors {'fad_m'} in its reactions.
#   - G3PDf_m has cofactor fad_m
# Warning: Enzyme FECOORCPLX3 has cofactor cu2_m counted multiple times, including subunits ['rtmCOX1'] and rtmCOX2.
# Warning: Enzyme FECOORCPLX4 has cofactor cu2_m counted multiple times, including subunits ['rtmCOX1'] and rtmCOX2.
# Enzyme rt2040 has cofactors {'fad_x'} in its reactions.
#   - ACOAD162f_x has cofactor fad_x
#   - ACOAD100f_x has cofactor fad_x
#   - ACOAD143f_x has cofactor fad_x
#   - ACOAD121af_x has cofactor fad_x
#   - ACOAD182f_x has cofactor fad_x
#   - ACOAD142f_x has cofactor fad_x
#   - ACOAD101df_x has cofactor fad_x
#   - ACOAD82ef_x has cofactor fad_x
#   - ACOAD140f_x has cofactor fad_x
#   - ACOAD181af_x has cofactor fad_x
#   - ACOAD60f_x has cofactor fad_x
#   - ACOAD160f_x has cofactor fad_x
#   - ACOAD161bf_x has cofactor fad_x
#   - ACOAD120f_x has cofactor fad_x
#   - ACOAD40f_x has cofactor fad_x
#   - ACOAD102ef_x has cofactor fad_x
#   - ACOAD161af_x has cofactor fad_x
#   - ACOAD80f_x has cofactor fad_x
#   - ACOAD141af_x has cofactor fad_x
#   - ACOAD141bf_x has cofactor fad_x
#   - ACOAD180f_x has cofactor fad_x
#   - ACOAD183f_x has cofactor fad_x
#   - ACOAD163f_x has cofactor fad_x
# Enzyme rt1644 has cofactors {'fad_m'} in its reactions.
#   - ACOADm50f_m has cofactor fad_m
# Enzyme rt3621 has cofactors {'fad_m'} in its reactions.
#   - GLUTCOADH_m has cofactor fad_m
# Enzyme rt6234 has cofactors {'fad_m'} in its reactions.
#   - PROD2_m has cofactor fad_m
# Enzyme rt5702 has cofactors {'fad_m'} in its reactions.
#   - ACOADm40f_m has cofactor fad_m
#   - ACOAD40f_m has cofactor fad_m
#   - ACOAD60f_m has cofactor fad_m
#   - ACOADm30f_m has cofactor fad_m
# Warning: Enzyme FECOORCPLX2 has cofactor cu2_m counted multiple times, including subunits ['rtmCOX1'] and rtmCOX2.
# Enzyme rt4202 has cofactors {'fad_m'} in its reactions.
#   - ACOAD120f_m has cofactor fad_m
#   - ACOAD100f_m has cofactor fad_m
#   - ACOAD80f_m has cofactor fad_m
# Warning: Enzyme FECOORCPLX1 has cofactor cu2_m counted multiple times, including subunits ['rtmCOX1'] and rtmCOX2.
