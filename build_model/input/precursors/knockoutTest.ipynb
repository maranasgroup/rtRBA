# %%
# Test if GSM model can make one or more metabolites
import pandas as pd
import cobra
from collections import OrderedDict
import copy
from copy import deepcopy
import os
from itertools import combinations

# %%
curr_dir = os.getcwd()
# Metabolic model (COBRApy json)
model = cobra.io.load_json_model(curr_dir + '/../iRhtoCN.json')
biomass = 'BIOMASS'

# %%
# Define the list of reactions to knock out
# all_reactions = ["reaction1_id", "reaction2_id", "reaction3_id"]
all_reactions = set(['CHTNDA_c','RPE_c','SDPDS_c','TKT1_c','TKT2_c','XU5PFGT_x'])
#all_reactions = set(['CHTNDA_c','RPE_c','SDPDS_c'])

# %%
# Function to perform FBA and categorize reactions
def categorize_reactions(model, reactions_to_knockout, essential_reactions, feasible_knockouts):
    # Create a copy of the model to avoid modifying the original model
    model_copy = model.copy()

    # Knock out the reactions in the current combination
    for reaction_id in reactions_to_knockout:
        reaction = model_copy.reactions.get_by_id(reaction_id)
        reaction.lower_bound = 0.0
        reaction.upper_bound = 0.0

    # Perform FBA on the modified model
    model_copy.objective = model.reactions.get_by_id(biomass)
    model_copy.objective_direction = "max"
    knockout_solution = model_copy.optimize()
    # knockout_solution = cobra.flux_analysis.optimize_minimal_flux(model_copy)

    # Check the objective value
    if knockout_solution.objective_value <= 0:
        essential_reactions.extend(reactions_to_knockout)
        print("Lethal knockout: ",reactions_to_knockout)
    else:
        feasible_knockouts.append(reactions_to_knockout)
        print("Nonlethal knockout: ",reactions_to_knockout)

# %%
# Lists to store results
essential_reactions = []
feasible_single_knockouts = []
feasible_knockout_combinations = [feasible_single_knockouts]

# %%
# Try single knockouts
for reaction_id in all_reactions:
    categorize_reactions(model, [reaction_id], essential_reactions, feasible_single_knockouts)
# Print the results
print("Essential Reactions:")
print(essential_reactions)
print("\nFeasible Single Knockouts:")
print(feasible_single_knockouts)
# Out:
# Nonlethal knockout:  ['SDPDS_c']
# Nonlethal knockout:  ['XU5PFGT_x']
# Nonlethal knockout:  ['TKT1_c']
# Nonlethal knockout:  ['TKT2_c']
# Nonlethal knockout:  ['CHTNDA_c']
# Nonlethal knockout:  ['RPE_c']
# Essential Reactions:
# []
#
# Feasible Single Knockouts:
# [['SDPDS_c'], ['XU5PFGT_x'], ['TKT1_c'], ['TKT2_c'], ['CHTNDA_c'], ['RPE_c']]

# %%
# Function to generate higher-order knockout combinations
def generate_higher_order_combinations(feasible_knockouts, n):
    higher_order_combinations = []
    for combo in combinations(feasible_knockouts, n):
        combined_knockout = [item for sublist in combo for item in sublist]
        higher_order_combinations.append(combined_knockout)
    return higher_order_combinations

# %%
# feasible_double_knockouts = []
# # Try double knockouts
# for combo in combinations(all_reactions, 2):
#     combined_knockout = list(combo)
#     categorize_reactions(model, combined_knockout, essential_reactions, feasible_double_knockouts)

# Try higher-order knockouts (e.g., triple, quadruple)
for order in range(2, len(all_reactions)):
    higher_order_combinations = generate_higher_order_combinations(feasible_knockout_combinations[-1], order)
    feasible_knockout_combinations.append([])
    for combo in higher_order_combinations:
        categorize_reactions(model, combo, essential_reactions, feasible_knockout_combinations[-1])
# Out:
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'RPE_c']
# Nonlethal knockout:  ['XU5PFGT_x', 'TKT1_c']
# Nonlethal knockout:  ['XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['XU5PFGT_x', 'CHTNDA_c']
# Nonlethal knockout:  ['XU5PFGT_x', 'RPE_c']
# Lethal knockout:  ['TKT1_c', 'TKT2_c']
# Nonlethal knockout:  ['TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['TKT1_c', 'RPE_c']
# Nonlethal knockout:  ['TKT2_c', 'CHTNDA_c']
# Lethal knockout:  ['TKT2_c', 'RPE_c']
# Nonlethal knockout:  ['CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT1_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT1_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'TKT1_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'TKT1_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'TKT2_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'TKT2_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'SDPDS_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'TKT1_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'TKT1_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'TKT1_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'RPE_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'RPE_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'RPE_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'SDPDS_c', 'RPE_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT1_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT1_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT1_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT1_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT2_c', 'XU5PFGT_x', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT2_c', 'XU5PFGT_x', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT2_c', 'TKT1_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT2_c', 'TKT1_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT2_c', 'TKT2_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'TKT2_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'CHTNDA_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'CHTNDA_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'CHTNDA_c', 'TKT1_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'CHTNDA_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'RPE_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'RPE_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'RPE_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'XU5PFGT_x', 'RPE_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'TKT1_c', 'CHTNDA_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'TKT1_c', 'CHTNDA_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'TKT1_c', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'TKT1_c', 'RPE_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'TKT1_c', 'RPE_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'XU5PFGT_x', 'TKT2_c', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT2_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'TKT1_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'TKT2_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'TKT2_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'SDPDS_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'TKT1_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'TKT1_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'SDPDS_c', 'RPE_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT1_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT1_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT1_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT1_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c', 'XU5PFGT_x', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c', 'XU5PFGT_x', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c', 'TKT1_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c', 'TKT2_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c', 'XU5PFGT_x', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'RPE_c', 'TKT1_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'RPE_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'RPE_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'XU5PFGT_x', 'RPE_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'TKT1_c', 'CHTNDA_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'TKT1_c', 'CHTNDA_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'TKT1_c', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'TKT1_c', 'RPE_c', 'TKT2_c', 'CHTNDA_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT1_c', 'TKT1_c', 'RPE_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT1_c', 'TKT2_c', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'SDPDS_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'TKT1_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'TKT2_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'XU5PFGT_x', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'TKT1_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'TKT1_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'TKT2_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'CHTNDA_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'TKT1_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'TKT2_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c', 'XU5PFGT_x', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c', 'TKT1_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c', 'TKT2_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'SDPDS_c', 'RPE_c', 'CHTNDA_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'TKT2_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c', 'XU5PFGT_x', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c', 'TKT1_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c', 'TKT1_c', 'RPE_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c', 'TKT2_c', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT1_c', 'CHTNDA_c', 'RPE_c']
# Nonlethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT2_c', 'XU5PFGT_x', 'CHTNDA_c']
# Lethal knockout:  ['SDPDS_c', 'TKT2_c', 'XU5PFGT_x', 'TKT2_c', 'XU5PFGT_x', 'RPE_c']

# %%
#print("\nFeasible Double Knockouts:")
#print(feasible_double_knockouts)
print("\nFeasible Knockout Combinations:")
for i, combinations in enumerate(feasible_knockout_combinations):
    print(f"Order-{i + 2} Knockouts:")
    print(combinations)
